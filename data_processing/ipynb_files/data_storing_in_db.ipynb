# %%
import os
import json
import mysql.connector

class DataStoring:
    def __init__(self, host=None, user=None, password=None, db=None):
        self.host = host
        self.user = user
        self.password = password
        self.connection = None
        self.cursor = None
        self.db = db
        self.code_path = r"C:\Users\haris\OneDrive\Desktop\Guvi\Projects\Amazon_Sales_Analysis\data_processing\ipynb_files"
        self.read_conifg()
        self.get_connection()
        self.create_db()
        # self.create_tables()

    def read_conifg(self):
        self.json_path = os.path.join(self.code_path, "db_config.json")
        self.config_data = json.load(open(self.json_path))
        self.host = self.config_data.get("host", "localhost")
        self.user = self.config_data.get("user", "root")
        self.password = self.config_data.get("password", "12345678")
        self.db = self.config_data.get("db", "amazon_sales_analysis")
    
    def save_config(self):
        with open(self.json_path, 'w') as file:
            json.dump(self.config_data, file, indent=4)

    def get_connection(self):
        self.read_conifg()
        try:
            if self.db and self.check_dbs():
                self.connection = mysql.connector.connect(
                                                        host=self.host,
                                                        user=self.user,
                                                        password=self.password,
                                                        database=self.db
                                                    )
                self.cursor = self.connection.cursor()
            else:
                self.connection = mysql.connector.connect(
                                                            host=self.host,
                                                            user=self.user,
                                                            password=self.password
                                                        )
                self.cursor = self.connection.cursor()
        except Exception as e:
            print(f"Couldn't connect to the MySQL server due to the error: {e}")

    def execute_query(self, query):
        if not self.connection or not self.connection.is_connected() or not self.cursor:
            self.get_connection()
        self.cursor.execute(query)
        return self.cursor
    
    def check_dbs(self):
        conn = mysql.connector.connect(
                                        host=self.host,
                                        user=self.user,
                                        password=self.password
                                    )

        cursor = conn.cursor()
        cursor.execute("SHOW DATABASES")

        databases = [db[0] for db in cursor.fetchall()]
        if self.db in databases:
            return True
        else:
            return False

    def create_db(self):
        if self.connection and self.cursor:
            try:
                self.db = "amazon_sales_analysis"
                self.cursor.execute(f"CREATE DATABASE IF NOT EXISTS {self.db}")
                self.connection.commit()
                self.config_data["db"] = self.db
                self.save_config()
            except Exception as e:
                print(f"Error creating database: {e}")
    
    def create_tables(self, table=None):
        self.read_conifg()
        try:
            self.cursor.execute(table if table else self.table)
            self.connection.commit()
        except Exception as e:
            print(f"Error creating table: {e}")

# %%
data_storing = DataStoring()
table = json.load(open(r"C:\Users\haris\OneDrive\Desktop\Guvi\Projects\Amazon_Sales_Analysis\data_processing\ipynb_files\db_config.json")).get("tables")
columns_sql = ", ".join([f"`{col}` TEXT" for col in data.columns])
table = table.format(table_name="cleaned_combined_data", columns=columns_sql)
print(table)
data_storing.create_tables(table=table)
# Out:
# CREATE TABLE IF NOT EXISTS cleaned_combined_data (id INT AUTO_INCREMENT PRIMARY KEY,`transaction_id` TEXT, `order_date` TEXT, `customer_id` TEXT, `product_id` TEXT, `product_name` TEXT, `category` TEXT, `subcategory` TEXT, `brand` TEXT, `original_price_inr` TEXT, `discount_percent` TEXT, `discounted_price_inr` TEXT, `quantity` TEXT, `subtotal_inr` TEXT, `delivery_charges` TEXT, `final_amount_inr` TEXT, `customer_city` TEXT, `customer_state` TEXT, `customer_tier` TEXT, `customer_spending_tier` TEXT, `customer_age_group` TEXT, `payment_method` TEXT, `delivery_days` TEXT, `delivery_type` TEXT, `is_prime_member` TEXT, `is_festival_sale` TEXT, `festival_name` TEXT, `customer_rating` TEXT, `return_status` TEXT, `order_month` TEXT, `order_year` TEXT, `order_quarter` TEXT, `product_weight_kg` TEXT, `is_prime_eligible` TEXT, `product_rating` TEXT, `clean_order_date` TEXT, `clean_original_price_inr` TEXT, `clean_discount_percent` TEXT, `clean_final_amount_inr` TEXT, `clean_delivery_charges` TEXT, `cleaned_customer_rating` TEXT, `cleaned_product_rating` TEXT, `cleaned_customer_city` TEXT, `cleaned_is_prime_member` TEXT, `cleaned_is_prime_eligible` TEXT, `cleaned_is_festival_sale` TEXT, `cleaned_category` TEXT, `cleaned_delivery_days` TEXT, `duplicate_type` TEXT, `corrected_price` TEXT, `standard_payment_method` TEXT);

# %%
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678",
    database="amazon_sales_analysis"
)

cursor = connection.cursor()

placeholders = ", ".join(["%s"] * len(data.columns))
columns_sql = ", ".join([f"`{col}`" for col in data.columns])  # backtick column names
insert_query = f"""
INSERT INTO cleaned_combined_data ({columns_sql})
VALUES ({placeholders});
"""

# --- Step 4: Insert Data ---
try:
    cursor.executemany(insert_query, data.to_records(index=False).tolist())
    connection.commit()
    print(f"✅ Successfully inserted {cursor.rowcount} rows into table.")
except mysql.connector.Error as err:
    print(f"❌ Error inserting data: {err}")
# Out:
# ❌ Error inserting data: 2055: Lost connection to MySQL server at 'localhost:3306', system error: Errno 8: EOF occurred in violation of protocol (_ssl.c:2417)

# %%
# import pandas as pd
# import mysql.connector

# csv_file = "your_file.csv"
# df = pd.read_csv(csv_file)
# df.columns = [col.strip().replace(" ", "_").replace("\n", "_") for col in df.columns]

connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345678",
    database="amazon_sales_analysis",
    ssl_disabled=True  # ✅ Disable SSL if not needed
)

cursor = connection.cursor()

cursor.execute("DELETE FROM cleaned_combined_data;")
connection.commit()

placeholders = ", ".join(["%s"] * len(data.columns))
columns_sql = ", ".join([f"`{col}`" for col in data.columns])
insert_query = f"""
INSERT INTO cleaned_combined_data ({columns_sql})
VALUES ({placeholders});
"""

# ✅ Insert in batches (e.g., 500 rows at a time)
batch_size = 500
data = data.to_records(index=False).tolist()

for i in range(0, len(data), batch_size):
    batch = data[i:i+batch_size]
    try:
        cursor.executemany(insert_query, batch)
        connection.commit()
        print(f"✅ Inserted rows {i+1} to {i+len(batch)}")
    except mysql.connector.Error as err:
        print(f"❌ Error inserting batch {i//batch_size + 1}: {err}")
        break

cursor.close()
connection.close()
# Out:
# ✅ Inserted rows 1 to 500
# ✅ Inserted rows 501 to 1000
# ✅ Inserted rows 1001 to 1500
# ✅ Inserted rows 1501 to 2000
# ✅ Inserted rows 2001 to 2500
# ✅ Inserted rows 2501 to 3000
# ✅ Inserted rows 3001 to 3500
# ✅ Inserted rows 3501 to 4000
# ✅ Inserted rows 4001 to 4500
# ✅ Inserted rows 4501 to 5000
# ✅ Inserted rows 5001 to 5500
# ✅ Inserted rows 5501 to 6000
# ✅ Inserted rows 6001 to 6500
# ✅ Inserted rows 6501 to 7000
# ✅ Inserted rows 7001 to 7500
# ✅ Inserted rows 7501 to 8000
# ✅ Inserted rows 8001 to 8500
# ✅ Inserted rows 8501 to 9000
# ✅ Inserted rows 9001 to 9500
# ✅ Inserted rows 9501 to 10000
# ✅ Inserted rows 10001 to 10500
# ✅ Inserted rows 10501 to 11000
# ✅ Inserted rows 11001 to 11500
# ✅ Inserted rows 11501 to 12000
# ✅ Inserted rows 12001 to 12500
# ✅ Inserted rows 12501 to 13000
# ✅ Inserted rows 13001 to 13500
# ✅ Inserted rows 13501 to 14000
# ✅ Inserted rows 14001 to 14500
# ✅ Inserted rows 14501 to 15000
# ✅ Inserted rows 15001 to 15500
# ✅ Inserted rows 15501 to 16000
# ✅ Inserted rows 16001 to 16500
# ✅ Inserted rows 16501 to 17000
# ✅ Inserted rows 17001 to 17500
# ✅ Inserted rows 17501 to 18000
# ✅ Inserted rows 18001 to 18500
# ✅ Inserted rows 18501 to 19000
# ✅ Inserted rows 19001 to 19500
# ✅ Inserted rows 19501 to 20000
# ✅ Inserted rows 20001 to 20500
# ✅ Inserted rows 20501 to 21000
# ✅ Inserted rows 21001 to 21500
# ✅ Inserted rows 21501 to 22000
# ✅ Inserted rows 22001 to 22500
# ✅ Inserted rows 22501 to 23000
# ✅ Inserted rows 23001 to 23500
# ✅ Inserted rows 23501 to 24000
# ✅ Inserted rows 24001 to 24500
# ✅ Inserted rows 24501 to 25000
# ✅ Inserted rows 25001 to 25500
# ✅ Inserted rows 25501 to 26000
# ✅ Inserted rows 26001 to 26500
# ✅ Inserted rows 26501 to 27000
# ✅ Inserted rows 27001 to 27500
# ✅ Inserted rows 27501 to 28000
# ✅ Inserted rows 28001 to 28500
# ✅ Inserted rows 28501 to 29000
# ✅ Inserted rows 29001 to 29500
# ✅ Inserted rows 29501 to 30000
# ✅ Inserted rows 30001 to 30500
# ✅ Inserted rows 30501 to 31000
# ✅ Inserted rows 31001 to 31500
# ✅ Inserted rows 31501 to 32000
# ✅ Inserted rows 32001 to 32500
# ✅ Inserted rows 32501 to 33000
# ✅ Inserted rows 33001 to 33500
# ✅ Inserted rows 33501 to 34000
# ✅ Inserted rows 34001 to 34500
# ✅ Inserted rows 34501 to 35000
# ✅ Inserted rows 35001 to 35500
# ✅ Inserted rows 35501 to 36000
# ✅ Inserted rows 36001 to 36500
# ✅ Inserted rows 36501 to 37000
# ✅ Inserted rows 37001 to 37500
# ✅ Inserted rows 37501 to 38000
# ✅ Inserted rows 38001 to 38500
# ✅ Inserted rows 38501 to 39000
# ✅ Inserted rows 39001 to 39500
# ✅ Inserted rows 39501 to 40000
# ✅ Inserted rows 40001 to 40500
# ✅ Inserted rows 40501 to 41000
# ✅ Inserted rows 41001 to 41500
# ✅ Inserted rows 41501 to 42000
# ✅ Inserted rows 42001 to 42500
# ✅ Inserted rows 42501 to 43000
# ✅ Inserted rows 43001 to 43500
# ✅ Inserted rows 43501 to 44000
# ✅ Inserted rows 44001 to 44500
# ✅ Inserted rows 44501 to 45000
# ✅ Inserted rows 45001 to 45500
# ✅ Inserted rows 45501 to 46000
# ✅ Inserted rows 46001 to 46500
# ✅ Inserted rows 46501 to 47000
# ✅ Inserted rows 47001 to 47500
# ✅ Inserted rows 47501 to 48000
# ✅ Inserted rows 48001 to 48500
# ✅ Inserted rows 48501 to 49000
# ✅ Inserted rows 49001 to 49500
# ✅ Inserted rows 49501 to 50000
# ✅ Inserted rows 50001 to 50500
# ✅ Inserted rows 50501 to 51000
# ✅ Inserted rows 51001 to 51500
# ✅ Inserted rows 51501 to 52000
# ✅ Inserted rows 52001 to 52500
# ✅ Inserted rows 52501 to 53000
# ✅ Inserted rows 53001 to 53500
# ✅ Inserted rows 53501 to 54000
# ✅ Inserted rows 54001 to 54500
# ✅ Inserted rows 54501 to 55000
# ✅ Inserted rows 55001 to 55500
# ✅ Inserted rows 55501 to 56000
# ✅ Inserted rows 56001 to 56500
# ✅ Inserted rows 56501 to 57000
# ✅ Inserted rows 57001 to 57500
# ✅ Inserted rows 57501 to 58000
# ✅ Inserted rows 58001 to 58500
# ✅ Inserted rows 58501 to 59000
# ✅ Inserted rows 59001 to 59500
# ✅ Inserted rows 59501 to 60000
# ✅ Inserted rows 60001 to 60500
# ✅ Inserted rows 60501 to 61000
# ✅ Inserted rows 61001 to 61500
# ✅ Inserted rows 61501 to 62000
# ✅ Inserted rows 62001 to 62500
# ✅ Inserted rows 62501 to 63000
# ✅ Inserted rows 63001 to 63500
# ✅ Inserted rows 63501 to 64000
# ✅ Inserted rows 64001 to 64500
# ✅ Inserted rows 64501 to 65000
# ✅ Inserted rows 65001 to 65500
# ✅ Inserted rows 65501 to 66000
# ✅ Inserted rows 66001 to 66500
# ✅ Inserted rows 66501 to 67000
# ✅ Inserted rows 67001 to 67500
# ✅ Inserted rows 67501 to 68000
# ✅ Inserted rows 68001 to 68500
# ✅ Inserted rows 68501 to 69000
# ✅ Inserted rows 69001 to 69500
# ✅ Inserted rows 69501 to 70000
# ✅ Inserted rows 70001 to 70500
# ✅ Inserted rows 70501 to 71000
# ✅ Inserted rows 71001 to 71500
# ✅ Inserted rows 71501 to 72000
# ✅ Inserted rows 72001 to 72500
# ✅ Inserted rows 72501 to 73000
# ✅ Inserted rows 73001 to 73500
# ✅ Inserted rows 73501 to 74000
# ✅ Inserted rows 74001 to 74500
# ✅ Inserted rows 74501 to 75000
# ✅ Inserted rows 75001 to 75500
# ✅ Inserted rows 75501 to 76000
# ✅ Inserted rows 76001 to 76500
# ✅ Inserted rows 76501 to 77000
# ✅ Inserted rows 77001 to 77500
# ✅ Inserted rows 77501 to 78000
# ✅ Inserted rows 78001 to 78500
# ✅ Inserted rows 78501 to 79000
# ✅ Inserted rows 79001 to 79500
# ✅ Inserted rows 79501 to 80000
# ✅ Inserted rows 80001 to 80500
# ✅ Inserted rows 80501 to 81000
# ✅ Inserted rows 81001 to 81500
# ✅ Inserted rows 81501 to 82000
# ✅ Inserted rows 82001 to 82500
# ✅ Inserted rows 82501 to 83000
# ✅ Inserted rows 83001 to 83500
# ✅ Inserted rows 83501 to 84000
# ✅ Inserted rows 84001 to 84500
# ✅ Inserted rows 84501 to 85000
# ✅ Inserted rows 85001 to 85500
# ✅ Inserted rows 85501 to 86000
# ✅ Inserted rows 86001 to 86500
# ✅ Inserted rows 86501 to 87000
# ✅ Inserted rows 87001 to 87500
# ✅ Inserted rows 87501 to 88000
# ✅ Inserted rows 88001 to 88500
# ✅ Inserted rows 88501 to 89000
# ✅ Inserted rows 89001 to 89500
# ✅ Inserted rows 89501 to 90000
# ✅ Inserted rows 90001 to 90500
# ✅ Inserted rows 90501 to 91000
# ✅ Inserted rows 91001 to 91500
# ✅ Inserted rows 91501 to 92000
# ✅ Inserted rows 92001 to 92500
# ✅ Inserted rows 92501 to 93000
# ✅ Inserted rows 93001 to 93500
# ✅ Inserted rows 93501 to 94000
# ✅ Inserted rows 94001 to 94500
# ✅ Inserted rows 94501 to 95000
# ✅ Inserted rows 95001 to 95500
# ✅ Inserted rows 95501 to 96000
# ✅ Inserted rows 96001 to 96500
# ✅ Inserted rows 96501 to 97000
# ✅ Inserted rows 97001 to 97500
# ✅ Inserted rows 97501 to 98000
# ✅ Inserted rows 98001 to 98500
# ✅ Inserted rows 98501 to 99000
# ✅ Inserted rows 99001 to 99500
# ✅ Inserted rows 99501 to 100000
# ✅ Inserted rows 100001 to 100500
# ✅ Inserted rows 100501 to 101000
# ✅ Inserted rows 101001 to 101500
# ✅ Inserted rows 101501 to 102000
# ✅ Inserted rows 102001 to 102500
# ✅ Inserted rows 102501 to 103000
# ✅ Inserted rows 103001 to 103500
# ✅ Inserted rows 103501 to 104000
# ✅ Inserted rows 104001 to 104500
# ✅ Inserted rows 104501 to 105000
# ✅ Inserted rows 105001 to 105500
# ✅ Inserted rows 105501 to 106000
# ✅ Inserted rows 106001 to 106500
# ✅ Inserted rows 106501 to 107000
# ✅ Inserted rows 107001 to 107500
# ✅ Inserted rows 107501 to 108000
# ✅ Inserted rows 108001 to 108500
# ✅ Inserted rows 108501 to 109000
# ✅ Inserted rows 109001 to 109500
# ✅ Inserted rows 109501 to 110000
# ✅ Inserted rows 110001 to 110500
# ✅ Inserted rows 110501 to 111000
# ✅ Inserted rows 111001 to 111500
# ✅ Inserted rows 111501 to 112000
# ✅ Inserted rows 112001 to 112500
# ✅ Inserted rows 112501 to 113000
# ✅ Inserted rows 113001 to 113500
# ✅ Inserted rows 113501 to 114000
# ✅ Inserted rows 114001 to 114500
# ✅ Inserted rows 114501 to 115000
# ✅ Inserted rows 115001 to 115500
# ✅ Inserted rows 115501 to 116000
# ✅ Inserted rows 116001 to 116500
# ✅ Inserted rows 116501 to 117000
# ✅ Inserted rows 117001 to 117500
# ✅ Inserted rows 117501 to 118000
# ✅ Inserted rows 118001 to 118500
# ✅ Inserted rows 118501 to 119000
# ✅ Inserted rows 119001 to 119500
# ✅ Inserted rows 119501 to 120000
# ✅ Inserted rows 120001 to 120500
# ✅ Inserted rows 120501 to 121000
# ✅ Inserted rows 121001 to 121500
# ✅ Inserted rows 121501 to 122000
# ✅ Inserted rows 122001 to 122500
# ✅ Inserted rows 122501 to 123000
# ✅ Inserted rows 123001 to 123500
# ✅ Inserted rows 123501 to 124000
# ✅ Inserted rows 124001 to 124500
# ✅ Inserted rows 124501 to 125000
# ✅ Inserted rows 125001 to 125500
# ✅ Inserted rows 125501 to 126000
# ✅ Inserted rows 126001 to 126500
# ✅ Inserted rows 126501 to 127000
# ✅ Inserted rows 127001 to 127500
# ✅ Inserted rows 127501 to 128000
# ✅ Inserted rows 128001 to 128500
# ✅ Inserted rows 128501 to 129000
# ✅ Inserted rows 129001 to 129500
# ✅ Inserted rows 129501 to 130000
# ✅ Inserted rows 130001 to 130500
# ✅ Inserted rows 130501 to 131000
# ✅ Inserted rows 131001 to 131500
# ✅ Inserted rows 131501 to 132000
# ✅ Inserted rows 132001 to 132500
# ✅ Inserted rows 132501 to 133000
# ✅ Inserted rows 133001 to 133500
# ✅ Inserted rows 133501 to 134000
# ✅ Inserted rows 134001 to 134500
# ✅ Inserted rows 134501 to 135000
# ✅ Inserted rows 135001 to 135500
# ✅ Inserted rows 135501 to 136000
# ✅ Inserted rows 136001 to 136500
# ✅ Inserted rows 136501 to 137000
# ✅ Inserted rows 137001 to 137500
# ✅ Inserted rows 137501 to 138000
# ✅ Inserted rows 138001 to 138500
# ✅ Inserted rows 138501 to 139000
# ✅ Inserted rows 139001 to 139500
# ✅ Inserted rows 139501 to 140000
# ✅ Inserted rows 140001 to 140500
# ✅ Inserted rows 140501 to 141000
# ✅ Inserted rows 141001 to 141500
# ✅ Inserted rows 141501 to 142000
# ✅ Inserted rows 142001 to 142500
# ✅ Inserted rows 142501 to 143000
# ✅ Inserted rows 143001 to 143500
# ✅ Inserted rows 143501 to 144000
# ✅ Inserted rows 144001 to 144500
# ✅ Inserted rows 144501 to 145000
# ✅ Inserted rows 145001 to 145500
# ✅ Inserted rows 145501 to 146000
# ✅ Inserted rows 146001 to 146500
# ✅ Inserted rows 146501 to 147000
# ✅ Inserted rows 147001 to 147500
# ✅ Inserted rows 147501 to 148000
# ✅ Inserted rows 148001 to 148500
# ✅ Inserted rows 148501 to 149000
# ✅ Inserted rows 149001 to 149500
# ✅ Inserted rows 149501 to 150000
# ✅ Inserted rows 150001 to 150500
# ✅ Inserted rows 150501 to 151000
# ✅ Inserted rows 151001 to 151500
# ✅ Inserted rows 151501 to 152000
# ✅ Inserted rows 152001 to 152500
# ✅ Inserted rows 152501 to 153000
# ✅ Inserted rows 153001 to 153500
# ✅ Inserted rows 153501 to 154000
# ✅ Inserted rows 154001 to 154500
# ✅ Inserted rows 154501 to 155000
# ✅ Inserted rows 155001 to 155500
# ✅ Inserted rows 155501 to 156000
# ✅ Inserted rows 156001 to 156500
# ✅ Inserted rows 156501 to 157000
# ✅ Inserted rows 157001 to 157500
# ✅ Inserted rows 157501 to 158000
# ✅ Inserted rows 158001 to 158500
# ✅ Inserted rows 158501 to 159000
# ✅ Inserted rows 159001 to 159500
# ✅ Inserted rows 159501 to 160000
# ✅ Inserted rows 160001 to 160500
# ✅ Inserted rows 160501 to 161000
# ✅ Inserted rows 161001 to 161500
# ✅ Inserted rows 161501 to 162000
# ✅ Inserted rows 162001 to 162500
# ✅ Inserted rows 162501 to 163000
# ✅ Inserted rows 163001 to 163500
# ✅ Inserted rows 163501 to 164000
# ✅ Inserted rows 164001 to 164500
# ✅ Inserted rows 164501 to 165000
# ✅ Inserted rows 165001 to 165500
# ✅ Inserted rows 165501 to 166000
# ✅ Inserted rows 166001 to 166500
# ✅ Inserted rows 166501 to 167000
# ✅ Inserted rows 167001 to 167500
# ✅ Inserted rows 167501 to 168000
# ✅ Inserted rows 168001 to 168500
# ✅ Inserted rows 168501 to 169000
# ✅ Inserted rows 169001 to 169500
# ✅ Inserted rows 169501 to 170000
# ✅ Inserted rows 170001 to 170500
# ✅ Inserted rows 170501 to 171000
# ✅ Inserted rows 171001 to 171500
# ✅ Inserted rows 171501 to 172000
# ✅ Inserted rows 172001 to 172500
# ✅ Inserted rows 172501 to 173000
# ✅ Inserted rows 173001 to 173500
# ✅ Inserted rows 173501 to 174000
# ✅ Inserted rows 174001 to 174500
# ✅ Inserted rows 174501 to 175000
# ✅ Inserted rows 175001 to 175500
# ✅ Inserted rows 175501 to 176000
# ✅ Inserted rows 176001 to 176500
# ✅ Inserted rows 176501 to 177000
# ✅ Inserted rows 177001 to 177500
# ✅ Inserted rows 177501 to 178000
# ✅ Inserted rows 178001 to 178500
# ✅ Inserted rows 178501 to 179000
# ✅ Inserted rows 179001 to 179500
# ✅ Inserted rows 179501 to 180000
# ✅ Inserted rows 180001 to 180500
# ✅ Inserted rows 180501 to 181000
# ✅ Inserted rows 181001 to 181500
# ✅ Inserted rows 181501 to 182000
# ✅ Inserted rows 182001 to 182500
# ✅ Inserted rows 182501 to 183000
# ✅ Inserted rows 183001 to 183500
# ✅ Inserted rows 183501 to 184000
# ✅ Inserted rows 184001 to 184500
# ✅ Inserted rows 184501 to 185000
# ✅ Inserted rows 185001 to 185500
# ✅ Inserted rows 185501 to 186000
# ✅ Inserted rows 186001 to 186500
# ✅ Inserted rows 186501 to 187000
# ✅ Inserted rows 187001 to 187500
# ✅ Inserted rows 187501 to 188000
# ✅ Inserted rows 188001 to 188500
# ✅ Inserted rows 188501 to 189000
# ✅ Inserted rows 189001 to 189500
# ✅ Inserted rows 189501 to 190000
# ✅ Inserted rows 190001 to 190500
# ✅ Inserted rows 190501 to 191000
# ✅ Inserted rows 191001 to 191500
# ✅ Inserted rows 191501 to 192000
# ✅ Inserted rows 192001 to 192500
# ✅ Inserted rows 192501 to 193000
# ✅ Inserted rows 193001 to 193500
# ✅ Inserted rows 193501 to 194000
# ✅ Inserted rows 194001 to 194500
# ✅ Inserted rows 194501 to 195000
# ✅ Inserted rows 195001 to 195500
# ✅ Inserted rows 195501 to 196000
# ✅ Inserted rows 196001 to 196500
# ✅ Inserted rows 196501 to 197000
# ✅ Inserted rows 197001 to 197500
# ✅ Inserted rows 197501 to 198000
# ✅ Inserted rows 198001 to 198500
# ✅ Inserted rows 198501 to 199000
# ✅ Inserted rows 199001 to 199500
# ✅ Inserted rows 199501 to 200000
# ✅ Inserted rows 200001 to 200500
# ✅ Inserted rows 200501 to 201000
# ✅ Inserted rows 201001 to 201500
# ✅ Inserted rows 201501 to 202000
# ✅ Inserted rows 202001 to 202500
# ✅ Inserted rows 202501 to 203000
# ✅ Inserted rows 203001 to 203500
# ✅ Inserted rows 203501 to 204000
# ✅ Inserted rows 204001 to 204500
# ✅ Inserted rows 204501 to 205000
# ✅ Inserted rows 205001 to 205500
# ✅ Inserted rows 205501 to 206000
# ✅ Inserted rows 206001 to 206500
# ✅ Inserted rows 206501 to 207000
# ✅ Inserted rows 207001 to 207500
# ✅ Inserted rows 207501 to 208000
# ✅ Inserted rows 208001 to 208500
# ✅ Inserted rows 208501 to 209000
# ✅ Inserted rows 209001 to 209500
# ✅ Inserted rows 209501 to 210000
# ✅ Inserted rows 210001 to 210500
# ✅ Inserted rows 210501 to 211000
# ✅ Inserted rows 211001 to 211500
# ✅ Inserted rows 211501 to 212000
# ✅ Inserted rows 212001 to 212500
# ✅ Inserted rows 212501 to 213000
# ✅ Inserted rows 213001 to 213500
# ✅ Inserted rows 213501 to 214000
# ✅ Inserted rows 214001 to 214500
# ✅ Inserted rows 214501 to 215000
# ✅ Inserted rows 215001 to 215500
# ✅ Inserted rows 215501 to 216000
# ✅ Inserted rows 216001 to 216500
# ✅ Inserted rows 216501 to 217000
# ✅ Inserted rows 217001 to 217500
# ✅ Inserted rows 217501 to 218000
# ✅ Inserted rows 218001 to 218500
# ✅ Inserted rows 218501 to 219000
# ✅ Inserted rows 219001 to 219500
# ✅ Inserted rows 219501 to 220000
# ✅ Inserted rows 220001 to 220500
# ✅ Inserted rows 220501 to 221000
# ✅ Inserted rows 221001 to 221500
# ✅ Inserted rows 221501 to 222000
# ✅ Inserted rows 222001 to 222500
# ✅ Inserted rows 222501 to 223000
# ✅ Inserted rows 223001 to 223500
# ✅ Inserted rows 223501 to 224000
# ✅ Inserted rows 224001 to 224500
# ✅ Inserted rows 224501 to 225000
# ✅ Inserted rows 225001 to 225500
# ✅ Inserted rows 225501 to 226000
# ✅ Inserted rows 226001 to 226500
# ✅ Inserted rows 226501 to 227000
# ✅ Inserted rows 227001 to 227500
# ✅ Inserted rows 227501 to 228000
# ✅ Inserted rows 228001 to 228500
# ✅ Inserted rows 228501 to 229000
# ✅ Inserted rows 229001 to 229500
# ✅ Inserted rows 229501 to 230000
# ✅ Inserted rows 230001 to 230500
# ✅ Inserted rows 230501 to 231000
# ✅ Inserted rows 231001 to 231500
# ✅ Inserted rows 231501 to 232000
# ✅ Inserted rows 232001 to 232500
# ✅ Inserted rows 232501 to 233000
# ✅ Inserted rows 233001 to 233500
# ✅ Inserted rows 233501 to 234000
# ✅ Inserted rows 234001 to 234500
# ✅ Inserted rows 234501 to 235000
# ✅ Inserted rows 235001 to 235500
# ✅ Inserted rows 235501 to 236000
# ✅ Inserted rows 236001 to 236500
# ✅ Inserted rows 236501 to 237000
# ✅ Inserted rows 237001 to 237500
# ✅ Inserted rows 237501 to 238000
# ✅ Inserted rows 238001 to 238500
# ✅ Inserted rows 238501 to 239000
# ✅ Inserted rows 239001 to 239500
# ✅ Inserted rows 239501 to 240000
# ✅ Inserted rows 240001 to 240500
# ✅ Inserted rows 240501 to 241000
# ✅ Inserted rows 241001 to 241500
# ✅ Inserted rows 241501 to 242000
# ✅ Inserted rows 242001 to 242500
# ✅ Inserted rows 242501 to 243000
# ✅ Inserted rows 243001 to 243500
# ✅ Inserted rows 243501 to 244000
# ✅ Inserted rows 244001 to 244500
# ✅ Inserted rows 244501 to 245000
# ✅ Inserted rows 245001 to 245500
# ✅ Inserted rows 245501 to 246000
# ✅ Inserted rows 246001 to 246500
# ✅ Inserted rows 246501 to 247000
# ✅ Inserted rows 247001 to 247500
# ✅ Inserted rows 247501 to 248000
# ✅ Inserted rows 248001 to 248500
# ✅ Inserted rows 248501 to 249000
# ✅ Inserted rows 249001 to 249500
# ✅ Inserted rows 249501 to 250000
# ✅ Inserted rows 250001 to 250500
# ✅ Inserted rows 250501 to 251000
# ✅ Inserted rows 251001 to 251500
# ✅ Inserted rows 251501 to 252000
# ✅ Inserted rows 252001 to 252500
# ✅ Inserted rows 252501 to 253000
# ✅ Inserted rows 253001 to 253500
# ✅ Inserted rows 253501 to 254000
# ✅ Inserted rows 254001 to 254500
# ✅ Inserted rows 254501 to 255000
# ✅ Inserted rows 255001 to 255500
# ✅ Inserted rows 255501 to 256000
# ✅ Inserted rows 256001 to 256500
# ✅ Inserted rows 256501 to 257000
# ✅ Inserted rows 257001 to 257500
# ✅ Inserted rows 257501 to 258000
# ✅ Inserted rows 258001 to 258500
# ✅ Inserted rows 258501 to 259000
# ✅ Inserted rows 259001 to 259500
# ✅ Inserted rows 259501 to 260000
# ✅ Inserted rows 260001 to 260500
# ✅ Inserted rows 260501 to 261000
# ✅ Inserted rows 261001 to 261500
# ✅ Inserted rows 261501 to 262000
# ✅ Inserted rows 262001 to 262500
# ✅ Inserted rows 262501 to 263000
# ✅ Inserted rows 263001 to 263500
# ✅ Inserted rows 263501 to 264000
# ✅ Inserted rows 264001 to 264500
# ✅ Inserted rows 264501 to 265000
# ✅ Inserted rows 265001 to 265500
# ✅ Inserted rows 265501 to 266000
# ✅ Inserted rows 266001 to 266500
# ✅ Inserted rows 266501 to 267000
# ✅ Inserted rows 267001 to 267500
# ✅ Inserted rows 267501 to 268000
# ✅ Inserted rows 268001 to 268500
# ✅ Inserted rows 268501 to 269000
# ✅ Inserted rows 269001 to 269500
# ✅ Inserted rows 269501 to 270000
# ✅ Inserted rows 270001 to 270500
# ✅ Inserted rows 270501 to 271000
# ✅ Inserted rows 271001 to 271500
# ✅ Inserted rows 271501 to 272000
# ✅ Inserted rows 272001 to 272500
# ✅ Inserted rows 272501 to 273000
# ✅ Inserted rows 273001 to 273500
# ✅ Inserted rows 273501 to 274000
# ✅ Inserted rows 274001 to 274500
# ✅ Inserted rows 274501 to 275000
# ✅ Inserted rows 275001 to 275500
# ✅ Inserted rows 275501 to 276000
# ✅ Inserted rows 276001 to 276500
# ✅ Inserted rows 276501 to 277000
# ✅ Inserted rows 277001 to 277500
# ✅ Inserted rows 277501 to 278000
# ✅ Inserted rows 278001 to 278500
# ✅ Inserted rows 278501 to 279000
# ✅ Inserted rows 279001 to 279500
# ✅ Inserted rows 279501 to 280000
# ✅ Inserted rows 280001 to 280500
# ✅ Inserted rows 280501 to 281000
# ✅ Inserted rows 281001 to 281500
# ✅ Inserted rows 281501 to 282000
# ✅ Inserted rows 282001 to 282500
# ✅ Inserted rows 282501 to 283000
# ✅ Inserted rows 283001 to 283500
# ✅ Inserted rows 283501 to 284000
# ✅ Inserted rows 284001 to 284500
# ✅ Inserted rows 284501 to 285000
# ✅ Inserted rows 285001 to 285500
# ✅ Inserted rows 285501 to 286000
# ✅ Inserted rows 286001 to 286500
# ✅ Inserted rows 286501 to 287000
# ✅ Inserted rows 287001 to 287500
# ✅ Inserted rows 287501 to 288000
# ✅ Inserted rows 288001 to 288500
# ✅ Inserted rows 288501 to 289000
# ✅ Inserted rows 289001 to 289500
# ✅ Inserted rows 289501 to 290000
# ✅ Inserted rows 290001 to 290500
# ✅ Inserted rows 290501 to 291000
# ✅ Inserted rows 291001 to 291500
# ✅ Inserted rows 291501 to 292000
# ✅ Inserted rows 292001 to 292500
# ✅ Inserted rows 292501 to 293000
# ✅ Inserted rows 293001 to 293500
# ✅ Inserted rows 293501 to 294000
# ✅ Inserted rows 294001 to 294500
# ✅ Inserted rows 294501 to 295000
# ✅ Inserted rows 295001 to 295500
# ✅ Inserted rows 295501 to 296000
# ✅ Inserted rows 296001 to 296500
# ✅ Inserted rows 296501 to 297000
# ✅ Inserted rows 297001 to 297500
# ✅ Inserted rows 297501 to 298000
# ✅ Inserted rows 298001 to 298500
# ✅ Inserted rows 298501 to 299000
# ✅ Inserted rows 299001 to 299500
# ✅ Inserted rows 299501 to 300000
# ✅ Inserted rows 300001 to 300500
# ✅ Inserted rows 300501 to 301000
# ✅ Inserted rows 301001 to 301500
# ✅ Inserted rows 301501 to 302000
# ✅ Inserted rows 302001 to 302500
# ✅ Inserted rows 302501 to 303000
# ✅ Inserted rows 303001 to 303500
# ✅ Inserted rows 303501 to 304000
# ✅ Inserted rows 304001 to 304500
# ✅ Inserted rows 304501 to 305000
# ✅ Inserted rows 305001 to 305500
# ✅ Inserted rows 305501 to 306000
# ✅ Inserted rows 306001 to 306500
# ✅ Inserted rows 306501 to 307000
# ✅ Inserted rows 307001 to 307500
# ✅ Inserted rows 307501 to 308000
# ✅ Inserted rows 308001 to 308500
# ✅ Inserted rows 308501 to 309000
# ✅ Inserted rows 309001 to 309500
# ✅ Inserted rows 309501 to 310000
# ✅ Inserted rows 310001 to 310500
# ✅ Inserted rows 310501 to 311000
# ✅ Inserted rows 311001 to 311500
# ✅ Inserted rows 311501 to 312000
# ✅ Inserted rows 312001 to 312500
# ✅ Inserted rows 312501 to 313000
# ✅ Inserted rows 313001 to 313500
# ✅ Inserted rows 313501 to 314000
# ✅ Inserted rows 314001 to 314500
# ✅ Inserted rows 314501 to 315000
# ✅ Inserted rows 315001 to 315500
# ✅ Inserted rows 315501 to 316000
# ✅ Inserted rows 316001 to 316500
# ✅ Inserted rows 316501 to 317000
# ✅ Inserted rows 317001 to 317500
# ✅ Inserted rows 317501 to 318000
# ✅ Inserted rows 318001 to 318500
# ✅ Inserted rows 318501 to 319000
# ✅ Inserted rows 319001 to 319500
# ✅ Inserted rows 319501 to 320000
# ✅ Inserted rows 320001 to 320500
# ✅ Inserted rows 320501 to 321000
# ✅ Inserted rows 321001 to 321500
# ✅ Inserted rows 321501 to 322000
# ✅ Inserted rows 322001 to 322500
# ✅ Inserted rows 322501 to 323000
# ✅ Inserted rows 323001 to 323500
# ✅ Inserted rows 323501 to 324000
# ✅ Inserted rows 324001 to 324500
# ✅ Inserted rows 324501 to 325000
# ✅ Inserted rows 325001 to 325500
# ✅ Inserted rows 325501 to 326000
# ✅ Inserted rows 326001 to 326500
# ✅ Inserted rows 326501 to 327000
# ✅ Inserted rows 327001 to 327500
# ✅ Inserted rows 327501 to 328000
# ✅ Inserted rows 328001 to 328500
# ✅ Inserted rows 328501 to 329000
# ✅ Inserted rows 329001 to 329500
# ✅ Inserted rows 329501 to 330000
# ✅ Inserted rows 330001 to 330500
# ✅ Inserted rows 330501 to 331000
# ✅ Inserted rows 331001 to 331500
# ✅ Inserted rows 331501 to 332000
# ✅ Inserted rows 332001 to 332500
# ✅ Inserted rows 332501 to 333000
# ✅ Inserted rows 333001 to 333500
# ✅ Inserted rows 333501 to 334000
# ✅ Inserted rows 334001 to 334500
# ✅ Inserted rows 334501 to 335000
# ✅ Inserted rows 335001 to 335500
# ✅ Inserted rows 335501 to 336000
# ✅ Inserted rows 336001 to 336500
# ✅ Inserted rows 336501 to 337000
# ✅ Inserted rows 337001 to 337500
# ✅ Inserted rows 337501 to 338000
# ✅ Inserted rows 338001 to 338500
# ✅ Inserted rows 338501 to 339000
# ✅ Inserted rows 339001 to 339500
# ✅ Inserted rows 339501 to 340000
# ✅ Inserted rows 340001 to 340500
# ✅ Inserted rows 340501 to 341000
# ✅ Inserted rows 341001 to 341500
# ✅ Inserted rows 341501 to 342000
# ✅ Inserted rows 342001 to 342500
# ✅ Inserted rows 342501 to 343000
# ✅ Inserted rows 343001 to 343500
# ✅ Inserted rows 343501 to 344000
# ✅ Inserted rows 344001 to 344500
# ✅ Inserted rows 344501 to 345000
# ✅ Inserted rows 345001 to 345500
# ✅ Inserted rows 345501 to 346000
# ✅ Inserted rows 346001 to 346500
# ✅ Inserted rows 346501 to 347000
# ✅ Inserted rows 347001 to 347500
# ✅ Inserted rows 347501 to 348000
# ✅ Inserted rows 348001 to 348500
# ✅ Inserted rows 348501 to 349000
# ✅ Inserted rows 349001 to 349500
# ✅ Inserted rows 349501 to 350000
# ✅ Inserted rows 350001 to 350500
# ✅ Inserted rows 350501 to 351000
# ✅ Inserted rows 351001 to 351500
# ✅ Inserted rows 351501 to 352000
# ✅ Inserted rows 352001 to 352500
# ✅ Inserted rows 352501 to 353000
# ✅ Inserted rows 353001 to 353500
# ✅ Inserted rows 353501 to 354000
# ✅ Inserted rows 354001 to 354500
# ✅ Inserted rows 354501 to 355000
# ✅ Inserted rows 355001 to 355500
# ✅ Inserted rows 355501 to 356000
# ✅ Inserted rows 356001 to 356500
# ✅ Inserted rows 356501 to 357000
# ✅ Inserted rows 357001 to 357500
# ✅ Inserted rows 357501 to 358000
# ✅ Inserted rows 358001 to 358500
# ✅ Inserted rows 358501 to 359000
# ✅ Inserted rows 359001 to 359500
# ✅ Inserted rows 359501 to 360000
# ✅ Inserted rows 360001 to 360500
# ✅ Inserted rows 360501 to 361000
# ✅ Inserted rows 361001 to 361500
# ✅ Inserted rows 361501 to 362000
# ✅ Inserted rows 362001 to 362500
# ✅ Inserted rows 362501 to 363000
# ✅ Inserted rows 363001 to 363500
# ✅ Inserted rows 363501 to 364000
# ✅ Inserted rows 364001 to 364500
# ✅ Inserted rows 364501 to 365000
# ✅ Inserted rows 365001 to 365500
# ✅ Inserted rows 365501 to 366000
# ✅ Inserted rows 366001 to 366500
# ✅ Inserted rows 366501 to 367000
# ✅ Inserted rows 367001 to 367500
# ✅ Inserted rows 367501 to 368000
# ✅ Inserted rows 368001 to 368500
# ✅ Inserted rows 368501 to 369000
# ✅ Inserted rows 369001 to 369500
# ✅ Inserted rows 369501 to 370000
# ✅ Inserted rows 370001 to 370500
# ✅ Inserted rows 370501 to 371000
# ✅ Inserted rows 371001 to 371500
# ✅ Inserted rows 371501 to 372000
# ✅ Inserted rows 372001 to 372500
# ✅ Inserted rows 372501 to 373000
# ✅ Inserted rows 373001 to 373500
# ✅ Inserted rows 373501 to 374000
# ✅ Inserted rows 374001 to 374500
# ✅ Inserted rows 374501 to 375000
# ✅ Inserted rows 375001 to 375500
# ✅ Inserted rows 375501 to 376000
# ✅ Inserted rows 376001 to 376500
# ✅ Inserted rows 376501 to 377000
# ✅ Inserted rows 377001 to 377500
# ✅ Inserted rows 377501 to 378000
# ✅ Inserted rows 378001 to 378500
# ✅ Inserted rows 378501 to 379000
# ✅ Inserted rows 379001 to 379500
# ✅ Inserted rows 379501 to 380000
# ✅ Inserted rows 380001 to 380500
# ✅ Inserted rows 380501 to 381000
# ✅ Inserted rows 381001 to 381500
# ✅ Inserted rows 381501 to 382000
# ✅ Inserted rows 382001 to 382500
# ✅ Inserted rows 382501 to 383000
# ✅ Inserted rows 383001 to 383500
# ✅ Inserted rows 383501 to 384000
# ✅ Inserted rows 384001 to 384500
# ✅ Inserted rows 384501 to 385000
# ✅ Inserted rows 385001 to 385500
# ✅ Inserted rows 385501 to 386000
# ✅ Inserted rows 386001 to 386500
# ✅ Inserted rows 386501 to 387000
# ✅ Inserted rows 387001 to 387500
# ✅ Inserted rows 387501 to 388000
# ✅ Inserted rows 388001 to 388500
# ✅ Inserted rows 388501 to 389000
# ✅ Inserted rows 389001 to 389500
# ✅ Inserted rows 389501 to 390000
# ✅ Inserted rows 390001 to 390500
# ✅ Inserted rows 390501 to 391000
# ✅ Inserted rows 391001 to 391500
# ✅ Inserted rows 391501 to 392000
# ✅ Inserted rows 392001 to 392500
# ✅ Inserted rows 392501 to 393000
# ✅ Inserted rows 393001 to 393500
# ✅ Inserted rows 393501 to 394000
# ✅ Inserted rows 394001 to 394500
# ✅ Inserted rows 394501 to 395000
# ✅ Inserted rows 395001 to 395500
# ✅ Inserted rows 395501 to 396000
# ✅ Inserted rows 396001 to 396500
# ✅ Inserted rows 396501 to 397000
# ✅ Inserted rows 397001 to 397500
# ✅ Inserted rows 397501 to 398000
# ✅ Inserted rows 398001 to 398500
# ✅ Inserted rows 398501 to 399000
# ✅ Inserted rows 399001 to 399500
# ✅ Inserted rows 399501 to 400000
# ✅ Inserted rows 400001 to 400500
# ✅ Inserted rows 400501 to 401000
# ✅ Inserted rows 401001 to 401500
# ✅ Inserted rows 401501 to 402000
# ✅ Inserted rows 402001 to 402500
# ✅ Inserted rows 402501 to 403000
# ✅ Inserted rows 403001 to 403500
# ✅ Inserted rows 403501 to 404000
# ✅ Inserted rows 404001 to 404500
# ✅ Inserted rows 404501 to 405000
# ✅ Inserted rows 405001 to 405500
# ✅ Inserted rows 405501 to 406000
# ✅ Inserted rows 406001 to 406500
# ✅ Inserted rows 406501 to 407000
# ✅ Inserted rows 407001 to 407500
# ✅ Inserted rows 407501 to 408000
# ✅ Inserted rows 408001 to 408500
# ✅ Inserted rows 408501 to 409000
# ✅ Inserted rows 409001 to 409500
# ✅ Inserted rows 409501 to 410000
# ✅ Inserted rows 410001 to 410500
# ✅ Inserted rows 410501 to 411000
# ✅ Inserted rows 411001 to 411500
# ✅ Inserted rows 411501 to 412000
# ✅ Inserted rows 412001 to 412500
# ✅ Inserted rows 412501 to 413000
# ✅ Inserted rows 413001 to 413500
# ✅ Inserted rows 413501 to 414000
# ✅ Inserted rows 414001 to 414500
# ✅ Inserted rows 414501 to 415000
# ✅ Inserted rows 415001 to 415500
# ✅ Inserted rows 415501 to 416000
# ✅ Inserted rows 416001 to 416500
# ✅ Inserted rows 416501 to 417000
# ✅ Inserted rows 417001 to 417500
# ✅ Inserted rows 417501 to 418000
# ✅ Inserted rows 418001 to 418500
# ✅ Inserted rows 418501 to 419000
# ✅ Inserted rows 419001 to 419500
# ✅ Inserted rows 419501 to 420000
# ✅ Inserted rows 420001 to 420500
# ✅ Inserted rows 420501 to 421000
# ✅ Inserted rows 421001 to 421500
# ✅ Inserted rows 421501 to 422000
# ✅ Inserted rows 422001 to 422500
# ✅ Inserted rows 422501 to 423000
# ✅ Inserted rows 423001 to 423500
# ✅ Inserted rows 423501 to 424000
# ✅ Inserted rows 424001 to 424500
# ✅ Inserted rows 424501 to 425000
# ✅ Inserted rows 425001 to 425500
# ✅ Inserted rows 425501 to 426000
# ✅ Inserted rows 426001 to 426500
# ✅ Inserted rows 426501 to 427000
# ✅ Inserted rows 427001 to 427500
# ✅ Inserted rows 427501 to 428000
# ✅ Inserted rows 428001 to 428500
# ✅ Inserted rows 428501 to 429000
# ✅ Inserted rows 429001 to 429500
# ✅ Inserted rows 429501 to 430000
# ✅ Inserted rows 430001 to 430500
# ✅ Inserted rows 430501 to 431000
# ✅ Inserted rows 431001 to 431500
# ✅ Inserted rows 431501 to 432000
# ✅ Inserted rows 432001 to 432500
# ✅ Inserted rows 432501 to 433000
# ✅ Inserted rows 433001 to 433500
# ✅ Inserted rows 433501 to 434000
# ✅ Inserted rows 434001 to 434500
# ✅ Inserted rows 434501 to 435000
# ✅ Inserted rows 435001 to 435500
# ✅ Inserted rows 435501 to 436000
# ✅ Inserted rows 436001 to 436500
# ✅ Inserted rows 436501 to 437000
# ✅ Inserted rows 437001 to 437500
# ✅ Inserted rows 437501 to 438000
# ✅ Inserted rows 438001 to 438500
# ✅ Inserted rows 438501 to 439000
# ✅ Inserted rows 439001 to 439500
# ✅ Inserted rows 439501 to 440000
# ✅ Inserted rows 440001 to 440500
# ✅ Inserted rows 440501 to 441000
# ✅ Inserted rows 441001 to 441500
# ✅ Inserted rows 441501 to 442000
# ✅ Inserted rows 442001 to 442500
# ✅ Inserted rows 442501 to 443000
# ✅ Inserted rows 443001 to 443500
# ✅ Inserted rows 443501 to 444000
# ✅ Inserted rows 444001 to 444500
# ✅ Inserted rows 444501 to 445000
# ✅ Inserted rows 445001 to 445500
# ✅ Inserted rows 445501 to 446000
# ✅ Inserted rows 446001 to 446500
# ✅ Inserted rows 446501 to 447000
# ✅ Inserted rows 447001 to 447500
# ✅ Inserted rows 447501 to 448000
# ✅ Inserted rows 448001 to 448500
# ✅ Inserted rows 448501 to 449000
# ✅ Inserted rows 449001 to 449500
# ✅ Inserted rows 449501 to 450000
# ✅ Inserted rows 450001 to 450500
# ✅ Inserted rows 450501 to 451000
# ✅ Inserted rows 451001 to 451500
# ✅ Inserted rows 451501 to 452000
# ✅ Inserted rows 452001 to 452500
# ✅ Inserted rows 452501 to 453000
# ✅ Inserted rows 453001 to 453500
# ✅ Inserted rows 453501 to 454000
# ✅ Inserted rows 454001 to 454500
# ✅ Inserted rows 454501 to 455000
# ✅ Inserted rows 455001 to 455500
# ✅ Inserted rows 455501 to 456000
# ✅ Inserted rows 456001 to 456500
# ✅ Inserted rows 456501 to 457000
# ✅ Inserted rows 457001 to 457500
# ✅ Inserted rows 457501 to 458000
# ✅ Inserted rows 458001 to 458500
# ✅ Inserted rows 458501 to 459000
# ✅ Inserted rows 459001 to 459500
# ✅ Inserted rows 459501 to 460000
# ✅ Inserted rows 460001 to 460500
# ✅ Inserted rows 460501 to 461000
# ✅ Inserted rows 461001 to 461500
# ✅ Inserted rows 461501 to 462000
# ✅ Inserted rows 462001 to 462500
# ✅ Inserted rows 462501 to 463000
# ✅ Inserted rows 463001 to 463500
# ✅ Inserted rows 463501 to 464000
# ✅ Inserted rows 464001 to 464500
# ✅ Inserted rows 464501 to 465000
# ✅ Inserted rows 465001 to 465500
# ✅ Inserted rows 465501 to 466000
# ✅ Inserted rows 466001 to 466500
# ✅ Inserted rows 466501 to 467000
# ✅ Inserted rows 467001 to 467500
# ✅ Inserted rows 467501 to 468000
# ✅ Inserted rows 468001 to 468500
# ✅ Inserted rows 468501 to 469000
# ✅ Inserted rows 469001 to 469500
# ✅ Inserted rows 469501 to 470000
# ✅ Inserted rows 470001 to 470500
# ✅ Inserted rows 470501 to 471000
# ✅ Inserted rows 471001 to 471500
# ✅ Inserted rows 471501 to 472000
# ✅ Inserted rows 472001 to 472500
# ✅ Inserted rows 472501 to 473000
# ✅ Inserted rows 473001 to 473500
# ✅ Inserted rows 473501 to 474000
# ✅ Inserted rows 474001 to 474500
# ✅ Inserted rows 474501 to 475000
# ✅ Inserted rows 475001 to 475500
# ✅ Inserted rows 475501 to 476000
# ✅ Inserted rows 476001 to 476500
# ✅ Inserted rows 476501 to 477000
# ✅ Inserted rows 477001 to 477500
# ✅ Inserted rows 477501 to 478000
# ✅ Inserted rows 478001 to 478500
# ✅ Inserted rows 478501 to 479000
# ✅ Inserted rows 479001 to 479500
# ✅ Inserted rows 479501 to 480000
# ✅ Inserted rows 480001 to 480500
# ✅ Inserted rows 480501 to 481000
# ✅ Inserted rows 481001 to 481500
# ✅ Inserted rows 481501 to 482000
# ✅ Inserted rows 482001 to 482500
# ✅ Inserted rows 482501 to 483000
# ✅ Inserted rows 483001 to 483500
# ✅ Inserted rows 483501 to 484000
# ✅ Inserted rows 484001 to 484500
# ✅ Inserted rows 484501 to 485000
# ✅ Inserted rows 485001 to 485500
# ✅ Inserted rows 485501 to 486000
# ✅ Inserted rows 486001 to 486500
# ✅ Inserted rows 486501 to 487000
# ✅ Inserted rows 487001 to 487500
# ✅ Inserted rows 487501 to 488000
# ✅ Inserted rows 488001 to 488500
# ✅ Inserted rows 488501 to 489000
# ✅ Inserted rows 489001 to 489500
# ✅ Inserted rows 489501 to 490000
# ✅ Inserted rows 490001 to 490500
# ✅ Inserted rows 490501 to 491000
# ✅ Inserted rows 491001 to 491500
# ✅ Inserted rows 491501 to 492000
# ✅ Inserted rows 492001 to 492500
# ✅ Inserted rows 492501 to 493000
# ✅ Inserted rows 493001 to 493500
# ✅ Inserted rows 493501 to 494000
# ✅ Inserted rows 494001 to 494500
# ✅ Inserted rows 494501 to 495000
# ✅ Inserted rows 495001 to 495500
# ✅ Inserted rows 495501 to 496000
# ✅ Inserted rows 496001 to 496500
# ✅ Inserted rows 496501 to 497000
# ✅ Inserted rows 497001 to 497500
# ✅ Inserted rows 497501 to 498000
# ✅ Inserted rows 498001 to 498500
# ✅ Inserted rows 498501 to 499000
# ✅ Inserted rows 499001 to 499500
# ✅ Inserted rows 499501 to 500000
# ✅ Inserted rows 500001 to 500500
# ✅ Inserted rows 500501 to 501000
# ✅ Inserted rows 501001 to 501500
# ✅ Inserted rows 501501 to 502000
# ✅ Inserted rows 502001 to 502500
# ✅ Inserted rows 502501 to 503000
# ✅ Inserted rows 503001 to 503500
# ✅ Inserted rows 503501 to 504000
# ✅ Inserted rows 504001 to 504500
# ✅ Inserted rows 504501 to 505000
# ✅ Inserted rows 505001 to 505500
# ✅ Inserted rows 505501 to 506000
# ✅ Inserted rows 506001 to 506500
# ✅ Inserted rows 506501 to 507000
# ✅ Inserted rows 507001 to 507500
# ✅ Inserted rows 507501 to 508000
# ✅ Inserted rows 508001 to 508500
# ✅ Inserted rows 508501 to 509000
# ✅ Inserted rows 509001 to 509500
# ✅ Inserted rows 509501 to 510000
# ✅ Inserted rows 510001 to 510500
# ✅ Inserted rows 510501 to 511000
# ✅ Inserted rows 511001 to 511500
# ✅ Inserted rows 511501 to 512000
# ✅ Inserted rows 512001 to 512500
# ✅ Inserted rows 512501 to 513000
# ✅ Inserted rows 513001 to 513500
# ✅ Inserted rows 513501 to 514000
# ✅ Inserted rows 514001 to 514500
# ✅ Inserted rows 514501 to 515000
# ✅ Inserted rows 515001 to 515500
# ✅ Inserted rows 515501 to 516000
# ✅ Inserted rows 516001 to 516500
# ✅ Inserted rows 516501 to 517000
# ✅ Inserted rows 517001 to 517500
# ✅ Inserted rows 517501 to 518000
# ✅ Inserted rows 518001 to 518500
# ✅ Inserted rows 518501 to 519000
# ✅ Inserted rows 519001 to 519500
# ✅ Inserted rows 519501 to 520000
# ✅ Inserted rows 520001 to 520500
# ✅ Inserted rows 520501 to 521000
# ✅ Inserted rows 521001 to 521500
# ✅ Inserted rows 521501 to 522000
# ✅ Inserted rows 522001 to 522500
# ✅ Inserted rows 522501 to 523000
# ✅ Inserted rows 523001 to 523500
# ✅ Inserted rows 523501 to 524000
# ✅ Inserted rows 524001 to 524500
# ✅ Inserted rows 524501 to 525000
# ✅ Inserted rows 525001 to 525500
# ✅ Inserted rows 525501 to 526000
# ✅ Inserted rows 526001 to 526500
# ✅ Inserted rows 526501 to 527000
# ✅ Inserted rows 527001 to 527500
# ✅ Inserted rows 527501 to 528000
# ✅ Inserted rows 528001 to 528500
# ✅ Inserted rows 528501 to 529000
# ✅ Inserted rows 529001 to 529500
# ✅ Inserted rows 529501 to 530000
# ✅ Inserted rows 530001 to 530500
# ✅ Inserted rows 530501 to 531000
# ✅ Inserted rows 531001 to 531500
# ✅ Inserted rows 531501 to 532000
# ✅ Inserted rows 532001 to 532500
# ✅ Inserted rows 532501 to 533000
# ✅ Inserted rows 533001 to 533500
# ✅ Inserted rows 533501 to 534000
# ✅ Inserted rows 534001 to 534500
# ✅ Inserted rows 534501 to 535000
# ✅ Inserted rows 535001 to 535500
# ✅ Inserted rows 535501 to 536000
# ✅ Inserted rows 536001 to 536500
# ✅ Inserted rows 536501 to 537000
# ✅ Inserted rows 537001 to 537500
# ✅ Inserted rows 537501 to 538000
# ✅ Inserted rows 538001 to 538500
# ✅ Inserted rows 538501 to 539000
# ✅ Inserted rows 539001 to 539500
# ✅ Inserted rows 539501 to 540000
# ✅ Inserted rows 540001 to 540500
# ✅ Inserted rows 540501 to 541000
# ✅ Inserted rows 541001 to 541500
# ✅ Inserted rows 541501 to 542000
# ✅ Inserted rows 542001 to 542500
# ✅ Inserted rows 542501 to 543000
# ✅ Inserted rows 543001 to 543500
# ✅ Inserted rows 543501 to 544000
# ✅ Inserted rows 544001 to 544500
# ✅ Inserted rows 544501 to 545000
# ✅ Inserted rows 545001 to 545500
# ✅ Inserted rows 545501 to 546000
# ✅ Inserted rows 546001 to 546500
# ✅ Inserted rows 546501 to 547000
# ✅ Inserted rows 547001 to 547500
# ✅ Inserted rows 547501 to 548000
# ✅ Inserted rows 548001 to 548500
# ✅ Inserted rows 548501 to 549000
# ✅ Inserted rows 549001 to 549500
# ✅ Inserted rows 549501 to 550000
# ✅ Inserted rows 550001 to 550500
# ✅ Inserted rows 550501 to 551000
# ✅ Inserted rows 551001 to 551500
# ✅ Inserted rows 551501 to 552000
# ✅ Inserted rows 552001 to 552500
# ✅ Inserted rows 552501 to 553000
# ✅ Inserted rows 553001 to 553500
# ✅ Inserted rows 553501 to 554000
# ✅ Inserted rows 554001 to 554500
# ✅ Inserted rows 554501 to 555000
# ✅ Inserted rows 555001 to 555500
# ✅ Inserted rows 555501 to 556000
# ✅ Inserted rows 556001 to 556500
# ✅ Inserted rows 556501 to 557000
# ✅ Inserted rows 557001 to 557500
# ✅ Inserted rows 557501 to 558000
# ✅ Inserted rows 558001 to 558500
# ✅ Inserted rows 558501 to 559000
# ✅ Inserted rows 559001 to 559500
# ✅ Inserted rows 559501 to 560000
# ✅ Inserted rows 560001 to 560500
# ✅ Inserted rows 560501 to 561000
# ✅ Inserted rows 561001 to 561500
# ✅ Inserted rows 561501 to 562000
# ✅ Inserted rows 562001 to 562500
# ✅ Inserted rows 562501 to 563000
# ✅ Inserted rows 563001 to 563500
# ✅ Inserted rows 563501 to 564000
# ✅ Inserted rows 564001 to 564500
# ✅ Inserted rows 564501 to 565000
# ✅ Inserted rows 565001 to 565500
# ✅ Inserted rows 565501 to 566000
# ✅ Inserted rows 566001 to 566500
# ✅ Inserted rows 566501 to 567000
# ✅ Inserted rows 567001 to 567500
# ✅ Inserted rows 567501 to 568000
# ✅ Inserted rows 568001 to 568500
# ✅ Inserted rows 568501 to 569000
# ✅ Inserted rows 569001 to 569500
# ✅ Inserted rows 569501 to 570000
# ✅ Inserted rows 570001 to 570500
# ✅ Inserted rows 570501 to 571000
# ✅ Inserted rows 571001 to 571500
# ✅ Inserted rows 571501 to 572000
# ✅ Inserted rows 572001 to 572500
# ✅ Inserted rows 572501 to 573000
# ✅ Inserted rows 573001 to 573500
# ✅ Inserted rows 573501 to 574000
# ✅ Inserted rows 574001 to 574500
# ✅ Inserted rows 574501 to 575000
# ✅ Inserted rows 575001 to 575500
# ✅ Inserted rows 575501 to 576000
# ✅ Inserted rows 576001 to 576500
# ✅ Inserted rows 576501 to 577000
# ✅ Inserted rows 577001 to 577500
# ✅ Inserted rows 577501 to 578000
# ✅ Inserted rows 578001 to 578500
# ✅ Inserted rows 578501 to 579000
# ✅ Inserted rows 579001 to 579500
# ✅ Inserted rows 579501 to 580000
# ✅ Inserted rows 580001 to 580500
# ✅ Inserted rows 580501 to 581000
# ✅ Inserted rows 581001 to 581500
# ✅ Inserted rows 581501 to 582000
# ✅ Inserted rows 582001 to 582500
# ✅ Inserted rows 582501 to 583000
# ✅ Inserted rows 583001 to 583500
# ✅ Inserted rows 583501 to 584000
# ✅ Inserted rows 584001 to 584500
# ✅ Inserted rows 584501 to 585000
# ✅ Inserted rows 585001 to 585500
# ✅ Inserted rows 585501 to 586000
# ✅ Inserted rows 586001 to 586500
# ✅ Inserted rows 586501 to 587000
# ✅ Inserted rows 587001 to 587500
# ✅ Inserted rows 587501 to 588000
# ✅ Inserted rows 588001 to 588500
# ✅ Inserted rows 588501 to 589000
# ✅ Inserted rows 589001 to 589500
# ✅ Inserted rows 589501 to 590000
# ✅ Inserted rows 590001 to 590500
# ✅ Inserted rows 590501 to 591000
# ✅ Inserted rows 591001 to 591500
# ✅ Inserted rows 591501 to 592000
# ✅ Inserted rows 592001 to 592500
# ✅ Inserted rows 592501 to 593000
# ✅ Inserted rows 593001 to 593500
# ✅ Inserted rows 593501 to 594000
# ✅ Inserted rows 594001 to 594500
# ✅ Inserted rows 594501 to 595000
# ✅ Inserted rows 595001 to 595500
# ✅ Inserted rows 595501 to 596000
# ✅ Inserted rows 596001 to 596500
# ✅ Inserted rows 596501 to 597000
# ✅ Inserted rows 597001 to 597500
# ✅ Inserted rows 597501 to 598000
# ✅ Inserted rows 598001 to 598500
# ✅ Inserted rows 598501 to 599000
# ✅ Inserted rows 599001 to 599500
# ✅ Inserted rows 599501 to 600000
# ✅ Inserted rows 600001 to 600500
# ✅ Inserted rows 600501 to 601000
# ✅ Inserted rows 601001 to 601500
# ✅ Inserted rows 601501 to 602000
# ✅ Inserted rows 602001 to 602500
# ✅ Inserted rows 602501 to 603000
# ✅ Inserted rows 603001 to 603500
# ✅ Inserted rows 603501 to 604000
# ✅ Inserted rows 604001 to 604500
# ✅ Inserted rows 604501 to 605000
# ✅ Inserted rows 605001 to 605500
# ✅ Inserted rows 605501 to 606000
# ✅ Inserted rows 606001 to 606500
# ✅ Inserted rows 606501 to 607000
# ✅ Inserted rows 607001 to 607500
# ✅ Inserted rows 607501 to 608000
# ✅ Inserted rows 608001 to 608500
# ✅ Inserted rows 608501 to 609000
# ✅ Inserted rows 609001 to 609500
# ✅ Inserted rows 609501 to 610000
# ✅ Inserted rows 610001 to 610500
# ✅ Inserted rows 610501 to 611000
# ✅ Inserted rows 611001 to 611500
# ✅ Inserted rows 611501 to 612000
# ✅ Inserted rows 612001 to 612500
# ✅ Inserted rows 612501 to 613000
# ✅ Inserted rows 613001 to 613500
# ✅ Inserted rows 613501 to 614000
# ✅ Inserted rows 614001 to 614500
# ✅ Inserted rows 614501 to 615000
# ✅ Inserted rows 615001 to 615500
# ✅ Inserted rows 615501 to 616000
# ✅ Inserted rows 616001 to 616500
# ✅ Inserted rows 616501 to 617000
# ✅ Inserted rows 617001 to 617500
# ✅ Inserted rows 617501 to 618000
# ✅ Inserted rows 618001 to 618500
# ✅ Inserted rows 618501 to 619000
# ✅ Inserted rows 619001 to 619500
# ✅ Inserted rows 619501 to 620000
# ✅ Inserted rows 620001 to 620500
# ✅ Inserted rows 620501 to 621000
# ✅ Inserted rows 621001 to 621500
# ✅ Inserted rows 621501 to 622000
# ✅ Inserted rows 622001 to 622500
# ✅ Inserted rows 622501 to 623000
# ✅ Inserted rows 623001 to 623500
# ✅ Inserted rows 623501 to 624000
# ✅ Inserted rows 624001 to 624500
# ✅ Inserted rows 624501 to 625000
# ✅ Inserted rows 625001 to 625500
# ✅ Inserted rows 625501 to 626000
# ✅ Inserted rows 626001 to 626500
# ✅ Inserted rows 626501 to 627000
# ✅ Inserted rows 627001 to 627500
# ✅ Inserted rows 627501 to 628000
# ✅ Inserted rows 628001 to 628500
# ✅ Inserted rows 628501 to 629000
# ✅ Inserted rows 629001 to 629500
# ✅ Inserted rows 629501 to 630000
# ✅ Inserted rows 630001 to 630500
# ✅ Inserted rows 630501 to 631000
# ✅ Inserted rows 631001 to 631500
# ✅ Inserted rows 631501 to 632000
# ✅ Inserted rows 632001 to 632500
# ✅ Inserted rows 632501 to 633000
# ✅ Inserted rows 633001 to 633500
# ✅ Inserted rows 633501 to 634000
# ✅ Inserted rows 634001 to 634500
# ✅ Inserted rows 634501 to 635000
# ✅ Inserted rows 635001 to 635500
# ✅ Inserted rows 635501 to 636000
# ✅ Inserted rows 636001 to 636500
# ✅ Inserted rows 636501 to 637000
# ✅ Inserted rows 637001 to 637500
# ✅ Inserted rows 637501 to 638000
# ✅ Inserted rows 638001 to 638500
# ✅ Inserted rows 638501 to 639000
# ✅ Inserted rows 639001 to 639500
# ✅ Inserted rows 639501 to 640000
# ✅ Inserted rows 640001 to 640500
# ✅ Inserted rows 640501 to 641000
# ✅ Inserted rows 641001 to 641500
# ✅ Inserted rows 641501 to 642000
# ✅ Inserted rows 642001 to 642500
# ✅ Inserted rows 642501 to 643000
# ✅ Inserted rows 643001 to 643500
# ✅ Inserted rows 643501 to 644000
# ✅ Inserted rows 644001 to 644500
# ✅ Inserted rows 644501 to 645000
# ✅ Inserted rows 645001 to 645500
# ✅ Inserted rows 645501 to 646000
# ✅ Inserted rows 646001 to 646500
# ✅ Inserted rows 646501 to 647000
# ✅ Inserted rows 647001 to 647500
# ✅ Inserted rows 647501 to 648000
# ✅ Inserted rows 648001 to 648500
# ✅ Inserted rows 648501 to 649000
# ✅ Inserted rows 649001 to 649500
# ✅ Inserted rows 649501 to 650000
# ✅ Inserted rows 650001 to 650500
# ✅ Inserted rows 650501 to 651000
# ✅ Inserted rows 651001 to 651500
# ✅ Inserted rows 651501 to 652000
# ✅ Inserted rows 652001 to 652500
# ✅ Inserted rows 652501 to 653000
# ✅ Inserted rows 653001 to 653500
# ✅ Inserted rows 653501 to 654000
# ✅ Inserted rows 654001 to 654500
# ✅ Inserted rows 654501 to 655000
# ✅ Inserted rows 655001 to 655500
# ✅ Inserted rows 655501 to 656000
# ✅ Inserted rows 656001 to 656500
# ✅ Inserted rows 656501 to 657000
# ✅ Inserted rows 657001 to 657500
# ✅ Inserted rows 657501 to 658000
# ✅ Inserted rows 658001 to 658500
# ✅ Inserted rows 658501 to 659000
# ✅ Inserted rows 659001 to 659500
# ✅ Inserted rows 659501 to 660000
# ✅ Inserted rows 660001 to 660500
# ✅ Inserted rows 660501 to 661000
# ✅ Inserted rows 661001 to 661500
# ✅ Inserted rows 661501 to 662000
# ✅ Inserted rows 662001 to 662500
# ✅ Inserted rows 662501 to 663000
# ✅ Inserted rows 663001 to 663500
# ✅ Inserted rows 663501 to 664000
# ✅ Inserted rows 664001 to 664500
# ✅ Inserted rows 664501 to 665000
# ✅ Inserted rows 665001 to 665500
# ✅ Inserted rows 665501 to 666000
# ✅ Inserted rows 666001 to 666500
# ✅ Inserted rows 666501 to 667000
# ✅ Inserted rows 667001 to 667500
# ✅ Inserted rows 667501 to 668000
# ✅ Inserted rows 668001 to 668500
# ✅ Inserted rows 668501 to 669000
# ✅ Inserted rows 669001 to 669500
# ✅ Inserted rows 669501 to 670000
# ✅ Inserted rows 670001 to 670500
# ✅ Inserted rows 670501 to 671000
# ✅ Inserted rows 671001 to 671500
# ✅ Inserted rows 671501 to 672000
# ✅ Inserted rows 672001 to 672500
# ✅ Inserted rows 672501 to 673000
# ✅ Inserted rows 673001 to 673500
# ✅ Inserted rows 673501 to 674000
# ✅ Inserted rows 674001 to 674500
# ✅ Inserted rows 674501 to 675000
# ✅ Inserted rows 675001 to 675500
# ✅ Inserted rows 675501 to 676000
# ✅ Inserted rows 676001 to 676500
# ✅ Inserted rows 676501 to 677000
# ✅ Inserted rows 677001 to 677500
# ✅ Inserted rows 677501 to 678000
# ✅ Inserted rows 678001 to 678500
# ✅ Inserted rows 678501 to 679000
# ✅ Inserted rows 679001 to 679500
# ✅ Inserted rows 679501 to 680000
# ✅ Inserted rows 680001 to 680500
# ✅ Inserted rows 680501 to 681000
# ✅ Inserted rows 681001 to 681500
# ✅ Inserted rows 681501 to 682000
# ✅ Inserted rows 682001 to 682500
# ✅ Inserted rows 682501 to 683000
# ✅ Inserted rows 683001 to 683500
# ✅ Inserted rows 683501 to 684000
# ✅ Inserted rows 684001 to 684500
# ✅ Inserted rows 684501 to 685000
# ✅ Inserted rows 685001 to 685500
# ✅ Inserted rows 685501 to 686000
# ✅ Inserted rows 686001 to 686500
# ✅ Inserted rows 686501 to 687000
# ✅ Inserted rows 687001 to 687500
# ✅ Inserted rows 687501 to 688000
# ✅ Inserted rows 688001 to 688500
# ✅ Inserted rows 688501 to 689000
# ✅ Inserted rows 689001 to 689500
# ✅ Inserted rows 689501 to 690000
# ✅ Inserted rows 690001 to 690500
# ✅ Inserted rows 690501 to 691000
# ✅ Inserted rows 691001 to 691500
# ✅ Inserted rows 691501 to 692000
# ✅ Inserted rows 692001 to 692500
# ✅ Inserted rows 692501 to 693000
# ✅ Inserted rows 693001 to 693500
# ✅ Inserted rows 693501 to 694000
# ✅ Inserted rows 694001 to 694500
# ✅ Inserted rows 694501 to 695000
# ✅ Inserted rows 695001 to 695500
# ✅ Inserted rows 695501 to 696000
# ✅ Inserted rows 696001 to 696500
# ✅ Inserted rows 696501 to 697000
# ✅ Inserted rows 697001 to 697500
# ✅ Inserted rows 697501 to 698000
# ✅ Inserted rows 698001 to 698500
# ✅ Inserted rows 698501 to 699000
# ✅ Inserted rows 699001 to 699500
# ✅ Inserted rows 699501 to 700000
# ✅ Inserted rows 700001 to 700500
# ✅ Inserted rows 700501 to 701000
# ✅ Inserted rows 701001 to 701500
# ✅ Inserted rows 701501 to 702000
# ✅ Inserted rows 702001 to 702500
# ✅ Inserted rows 702501 to 703000
# ✅ Inserted rows 703001 to 703500
# ✅ Inserted rows 703501 to 704000
# ✅ Inserted rows 704001 to 704500
# ✅ Inserted rows 704501 to 705000
# ✅ Inserted rows 705001 to 705500
# ✅ Inserted rows 705501 to 706000
# ✅ Inserted rows 706001 to 706500
# ✅ Inserted rows 706501 to 707000
# ✅ Inserted rows 707001 to 707500
# ✅ Inserted rows 707501 to 708000
# ✅ Inserted rows 708001 to 708500
# ✅ Inserted rows 708501 to 709000
# ✅ Inserted rows 709001 to 709500
# ✅ Inserted rows 709501 to 710000
# ✅ Inserted rows 710001 to 710500
# ✅ Inserted rows 710501 to 711000
# ✅ Inserted rows 711001 to 711500
# ✅ Inserted rows 711501 to 712000
# ✅ Inserted rows 712001 to 712500
# ✅ Inserted rows 712501 to 713000
# ✅ Inserted rows 713001 to 713500
# ✅ Inserted rows 713501 to 714000
# ✅ Inserted rows 714001 to 714500
# ✅ Inserted rows 714501 to 715000
# ✅ Inserted rows 715001 to 715500
# ✅ Inserted rows 715501 to 716000
# ✅ Inserted rows 716001 to 716500
# ✅ Inserted rows 716501 to 717000
# ✅ Inserted rows 717001 to 717500
# ✅ Inserted rows 717501 to 718000
# ✅ Inserted rows 718001 to 718500
# ✅ Inserted rows 718501 to 719000
# ✅ Inserted rows 719001 to 719500
# ✅ Inserted rows 719501 to 720000
# ✅ Inserted rows 720001 to 720500
# ✅ Inserted rows 720501 to 721000
# ✅ Inserted rows 721001 to 721500
# ✅ Inserted rows 721501 to 722000
# ✅ Inserted rows 722001 to 722500
# ✅ Inserted rows 722501 to 723000
# ✅ Inserted rows 723001 to 723500
# ✅ Inserted rows 723501 to 724000
# ✅ Inserted rows 724001 to 724500
# ✅ Inserted rows 724501 to 725000
# ✅ Inserted rows 725001 to 725500
# ✅ Inserted rows 725501 to 726000
# ✅ Inserted rows 726001 to 726500
# ✅ Inserted rows 726501 to 727000
# ✅ Inserted rows 727001 to 727500
# ✅ Inserted rows 727501 to 728000
# ✅ Inserted rows 728001 to 728500
# ✅ Inserted rows 728501 to 729000
# ✅ Inserted rows 729001 to 729500
# ✅ Inserted rows 729501 to 730000
# ✅ Inserted rows 730001 to 730500
# ✅ Inserted rows 730501 to 731000
# ✅ Inserted rows 731001 to 731500
# ✅ Inserted rows 731501 to 732000
# ✅ Inserted rows 732001 to 732500
# ✅ Inserted rows 732501 to 733000
# ✅ Inserted rows 733001 to 733500
# ...
# ✅ Inserted rows 893501 to 894000
# ✅ Inserted rows 894001 to 894500
# ✅ Inserted rows 894501 to 895000
# ✅ Inserted rows 895001 to 895500
# ✅ Inserted rows 895501 to 896000
# ✅ Inserted rows 896001 to 896500
# ✅ Inserted rows 896501 to 897000
# ✅ Inserted rows 897001 to 897500
# ✅ Inserted rows 897501 to 898000
# ✅ Inserted rows 898001 to 898500
# ✅ Inserted rows 898501 to 899000
# ✅ Inserted rows 899001 to 899500
# ✅ Inserted rows 899501 to 900000
# ✅ Inserted rows 900001 to 900500
# ✅ Inserted rows 900501 to 901000
# ✅ Inserted rows 901001 to 901500
# ✅ Inserted rows 901501 to 902000
# ✅ Inserted rows 902001 to 902500
# ✅ Inserted rows 902501 to 903000
# ✅ Inserted rows 903001 to 903500
# ✅ Inserted rows 903501 to 904000
# ✅ Inserted rows 904001 to 904500
# ✅ Inserted rows 904501 to 905000
# ✅ Inserted rows 905001 to 905500
# ✅ Inserted rows 905501 to 906000
# ✅ Inserted rows 906001 to 906500
# ✅ Inserted rows 906501 to 907000
# ✅ Inserted rows 907001 to 907500
# ✅ Inserted rows 907501 to 908000
# ✅ Inserted rows 908001 to 908500
# ✅ Inserted rows 908501 to 909000
# ✅ Inserted rows 909001 to 909500
# ✅ Inserted rows 909501 to 910000
# ✅ Inserted rows 910001 to 910500
# ✅ Inserted rows 910501 to 911000
# ✅ Inserted rows 911001 to 911500
# ✅ Inserted rows 911501 to 912000
# ✅ Inserted rows 912001 to 912500
# ✅ Inserted rows 912501 to 913000
# ✅ Inserted rows 913001 to 913500
# ✅ Inserted rows 913501 to 914000
# ✅ Inserted rows 914001 to 914500
# ✅ Inserted rows 914501 to 915000
# ✅ Inserted rows 915001 to 915500
# ✅ Inserted rows 915501 to 916000
# ✅ Inserted rows 916001 to 916500
# ✅ Inserted rows 916501 to 917000
# ✅ Inserted rows 917001 to 917500
# ✅ Inserted rows 917501 to 918000
# ✅ Inserted rows 918001 to 918500
# ✅ Inserted rows 918501 to 919000
# ✅ Inserted rows 919001 to 919500
# ✅ Inserted rows 919501 to 920000
# ✅ Inserted rows 920001 to 920500
# ✅ Inserted rows 920501 to 921000
# ✅ Inserted rows 921001 to 921500
# ✅ Inserted rows 921501 to 922000
# ✅ Inserted rows 922001 to 922500
# ✅ Inserted rows 922501 to 923000
# ✅ Inserted rows 923001 to 923500
# ✅ Inserted rows 923501 to 924000
# ✅ Inserted rows 924001 to 924500
# ✅ Inserted rows 924501 to 925000
# ✅ Inserted rows 925001 to 925500
# ✅ Inserted rows 925501 to 926000
# ✅ Inserted rows 926001 to 926500
# ✅ Inserted rows 926501 to 927000
# ✅ Inserted rows 927001 to 927500
# ✅ Inserted rows 927501 to 928000
# ✅ Inserted rows 928001 to 928500
# ✅ Inserted rows 928501 to 929000
# ✅ Inserted rows 929001 to 929500
# ✅ Inserted rows 929501 to 930000
# ✅ Inserted rows 930001 to 930500
# ✅ Inserted rows 930501 to 931000
# ✅ Inserted rows 931001 to 931500
# ✅ Inserted rows 931501 to 932000
# ✅ Inserted rows 932001 to 932500
# ✅ Inserted rows 932501 to 933000
# ✅ Inserted rows 933001 to 933500
# ✅ Inserted rows 933501 to 934000
# ✅ Inserted rows 934001 to 934500
# ✅ Inserted rows 934501 to 935000
# ✅ Inserted rows 935001 to 935500
# ✅ Inserted rows 935501 to 936000
# ✅ Inserted rows 936001 to 936500
# ✅ Inserted rows 936501 to 937000
# ✅ Inserted rows 937001 to 937500
# ✅ Inserted rows 937501 to 938000
# ✅ Inserted rows 938001 to 938500
# ✅ Inserted rows 938501 to 939000
# ✅ Inserted rows 939001 to 939500
# ✅ Inserted rows 939501 to 940000
# ✅ Inserted rows 940001 to 940500
# ✅ Inserted rows 940501 to 941000
# ✅ Inserted rows 941001 to 941500
# ✅ Inserted rows 941501 to 942000
# ✅ Inserted rows 942001 to 942500
# ✅ Inserted rows 942501 to 943000
# ✅ Inserted rows 943001 to 943500
# ✅ Inserted rows 943501 to 944000
# ✅ Inserted rows 944001 to 944500
# ✅ Inserted rows 944501 to 945000
# ✅ Inserted rows 945001 to 945500
# ✅ Inserted rows 945501 to 946000
# ✅ Inserted rows 946001 to 946500
# ✅ Inserted rows 946501 to 947000
# ✅ Inserted rows 947001 to 947500
# ✅ Inserted rows 947501 to 948000
# ✅ Inserted rows 948001 to 948500
# ✅ Inserted rows 948501 to 949000
# ✅ Inserted rows 949001 to 949500
# ✅ Inserted rows 949501 to 950000
# ✅ Inserted rows 950001 to 950500
# ✅ Inserted rows 950501 to 951000
# ✅ Inserted rows 951001 to 951500
# ✅ Inserted rows 951501 to 952000
# ✅ Inserted rows 952001 to 952500
# ✅ Inserted rows 952501 to 953000
# ✅ Inserted rows 953001 to 953500
# ✅ Inserted rows 953501 to 954000
# ✅ Inserted rows 954001 to 954500
# ✅ Inserted rows 954501 to 955000
# ✅ Inserted rows 955001 to 955500
# ✅ Inserted rows 955501 to 956000
# ✅ Inserted rows 956001 to 956500
# ✅ Inserted rows 956501 to 957000
# ✅ Inserted rows 957001 to 957500
# ✅ Inserted rows 957501 to 958000
# ✅ Inserted rows 958001 to 958500
# ✅ Inserted rows 958501 to 959000
# ✅ Inserted rows 959001 to 959500
# ✅ Inserted rows 959501 to 960000
# ✅ Inserted rows 960001 to 960500
# ✅ Inserted rows 960501 to 961000
# ✅ Inserted rows 961001 to 961500
# ✅ Inserted rows 961501 to 962000
# ✅ Inserted rows 962001 to 962500
# ✅ Inserted rows 962501 to 963000
# ✅ Inserted rows 963001 to 963500
# ✅ Inserted rows 963501 to 964000
# ✅ Inserted rows 964001 to 964500
# ✅ Inserted rows 964501 to 965000
# ✅ Inserted rows 965001 to 965500
# ✅ Inserted rows 965501 to 966000
# ✅ Inserted rows 966001 to 966500
# ✅ Inserted rows 966501 to 967000
# ✅ Inserted rows 967001 to 967500
# ✅ Inserted rows 967501 to 968000
# ✅ Inserted rows 968001 to 968500
# ✅ Inserted rows 968501 to 969000
# ✅ Inserted rows 969001 to 969500
# ✅ Inserted rows 969501 to 970000
# ✅ Inserted rows 970001 to 970500
# ✅ Inserted rows 970501 to 971000
# ✅ Inserted rows 971001 to 971500
# ✅ Inserted rows 971501 to 972000
# ✅ Inserted rows 972001 to 972500
# ✅ Inserted rows 972501 to 973000
# ✅ Inserted rows 973001 to 973500
# ✅ Inserted rows 973501 to 974000
# ✅ Inserted rows 974001 to 974500
# ✅ Inserted rows 974501 to 975000
# ✅ Inserted rows 975001 to 975500
# ✅ Inserted rows 975501 to 976000
# ✅ Inserted rows 976001 to 976500
# ✅ Inserted rows 976501 to 977000
# ✅ Inserted rows 977001 to 977500
# ✅ Inserted rows 977501 to 978000
# ✅ Inserted rows 978001 to 978500
# ✅ Inserted rows 978501 to 979000
# ✅ Inserted rows 979001 to 979500
# ✅ Inserted rows 979501 to 980000
# ✅ Inserted rows 980001 to 980500
# ✅ Inserted rows 980501 to 981000
# ✅ Inserted rows 981001 to 981500
# ✅ Inserted rows 981501 to 982000
# ✅ Inserted rows 982001 to 982500
# ✅ Inserted rows 982501 to 983000
# ✅ Inserted rows 983001 to 983500
# ✅ Inserted rows 983501 to 984000
# ✅ Inserted rows 984001 to 984500
# ✅ Inserted rows 984501 to 985000
# ✅ Inserted rows 985001 to 985500
# ✅ Inserted rows 985501 to 986000
# ✅ Inserted rows 986001 to 986500
# ✅ Inserted rows 986501 to 987000
# ✅ Inserted rows 987001 to 987500
# ✅ Inserted rows 987501 to 988000
# ✅ Inserted rows 988001 to 988500
# ✅ Inserted rows 988501 to 989000
# ✅ Inserted rows 989001 to 989500
# ✅ Inserted rows 989501 to 990000
# ✅ Inserted rows 990001 to 990500
# ✅ Inserted rows 990501 to 991000
# ✅ Inserted rows 991001 to 991500
# ✅ Inserted rows 991501 to 992000
# ✅ Inserted rows 992001 to 992500
# ✅ Inserted rows 992501 to 993000
# ✅ Inserted rows 993001 to 993500
# ✅ Inserted rows 993501 to 994000
# ✅ Inserted rows 994001 to 994500
# ✅ Inserted rows 994501 to 995000
# ✅ Inserted rows 995001 to 995500
# ✅ Inserted rows 995501 to 996000
# ✅ Inserted rows 996001 to 996500
# ✅ Inserted rows 996501 to 997000
# ✅ Inserted rows 997001 to 997500
# ✅ Inserted rows 997501 to 998000
# ✅ Inserted rows 998001 to 998500
# ✅ Inserted rows 998501 to 999000
# ✅ Inserted rows 999001 to 999500
# ✅ Inserted rows 999501 to 1000000
# ✅ Inserted rows 1000001 to 1000500
# ✅ Inserted rows 1000501 to 1001000
# ✅ Inserted rows 1001001 to 1001500
# ✅ Inserted rows 1001501 to 1002000
# ✅ Inserted rows 1002001 to 1002500
# ✅ Inserted rows 1002501 to 1003000
# ✅ Inserted rows 1003001 to 1003500
# ✅ Inserted rows 1003501 to 1004000
# ✅ Inserted rows 1004001 to 1004500
# ✅ Inserted rows 1004501 to 1005000
# ✅ Inserted rows 1005001 to 1005500
# ✅ Inserted rows 1005501 to 1006000
# ✅ Inserted rows 1006001 to 1006500
# ✅ Inserted rows 1006501 to 1007000
# ✅ Inserted rows 1007001 to 1007500
# ✅ Inserted rows 1007501 to 1008000
# ✅ Inserted rows 1008001 to 1008500
# ✅ Inserted rows 1008501 to 1009000
# ✅ Inserted rows 1009001 to 1009500
# ✅ Inserted rows 1009501 to 1010000
# ✅ Inserted rows 1010001 to 1010500
# ✅ Inserted rows 1010501 to 1011000
# ✅ Inserted rows 1011001 to 1011500
# ✅ Inserted rows 1011501 to 1012000
# ✅ Inserted rows 1012001 to 1012500
# ✅ Inserted rows 1012501 to 1013000
# ✅ Inserted rows 1013001 to 1013500
# ✅ Inserted rows 1013501 to 1014000
# ✅ Inserted rows 1014001 to 1014500
# ✅ Inserted rows 1014501 to 1015000
# ✅ Inserted rows 1015001 to 1015500
# ✅ Inserted rows 1015501 to 1016000
# ✅ Inserted rows 1016001 to 1016500
# ✅ Inserted rows 1016501 to 1017000
# ✅ Inserted rows 1017001 to 1017500
# ✅ Inserted rows 1017501 to 1018000
# ✅ Inserted rows 1018001 to 1018500
# ✅ Inserted rows 1018501 to 1019000
# ✅ Inserted rows 1019001 to 1019500
# ✅ Inserted rows 1019501 to 1020000
# ✅ Inserted rows 1020001 to 1020500
# ✅ Inserted rows 1020501 to 1021000
# ✅ Inserted rows 1021001 to 1021500
# ✅ Inserted rows 1021501 to 1022000
# ✅ Inserted rows 1022001 to 1022500
# ✅ Inserted rows 1022501 to 1023000
# ✅ Inserted rows 1023001 to 1023500
# ✅ Inserted rows 1023501 to 1024000
# ✅ Inserted rows 1024001 to 1024500
# ✅ Inserted rows 1024501 to 1025000
# ✅ Inserted rows 1025001 to 1025500
# ✅ Inserted rows 1025501 to 1026000
# ✅ Inserted rows 1026001 to 1026500
# ✅ Inserted rows 1026501 to 1027000
# ✅ Inserted rows 1027001 to 1027500
# ✅ Inserted rows 1027501 to 1028000
# ✅ Inserted rows 1028001 to 1028500
# ✅ Inserted rows 1028501 to 1029000
# ✅ Inserted rows 1029001 to 1029500
# ✅ Inserted rows 1029501 to 1030000
# ✅ Inserted rows 1030001 to 1030500
# ✅ Inserted rows 1030501 to 1031000
# ✅ Inserted rows 1031001 to 1031500
# ✅ Inserted rows 1031501 to 1032000
# ✅ Inserted rows 1032001 to 1032500
# ✅ Inserted rows 1032501 to 1033000
# ✅ Inserted rows 1033001 to 1033500
# ✅ Inserted rows 1033501 to 1034000
# ✅ Inserted rows 1034001 to 1034500
# ✅ Inserted rows 1034501 to 1035000
# ✅ Inserted rows 1035001 to 1035500
# ✅ Inserted rows 1035501 to 1036000
# ✅ Inserted rows 1036001 to 1036500
# ✅ Inserted rows 1036501 to 1037000
# ✅ Inserted rows 1037001 to 1037500
# ✅ Inserted rows 1037501 to 1038000
# ✅ Inserted rows 1038001 to 1038500
# ✅ Inserted rows 1038501 to 1039000
# ✅ Inserted rows 1039001 to 1039500
# ✅ Inserted rows 1039501 to 1040000
# ✅ Inserted rows 1040001 to 1040500
# ✅ Inserted rows 1040501 to 1041000
# ✅ Inserted rows 1041001 to 1041500
# ✅ Inserted rows 1041501 to 1042000
# ✅ Inserted rows 1042001 to 1042500
# ✅ Inserted rows 1042501 to 1043000
# ✅ Inserted rows 1043001 to 1043500
# ✅ Inserted rows 1043501 to 1044000
# ✅ Inserted rows 1044001 to 1044500
# ✅ Inserted rows 1044501 to 1045000
# ✅ Inserted rows 1045001 to 1045500
# ✅ Inserted rows 1045501 to 1046000
# ✅ Inserted rows 1046001 to 1046500
# ✅ Inserted rows 1046501 to 1047000
# ✅ Inserted rows 1047001 to 1047500
# ✅ Inserted rows 1047501 to 1048000
# ✅ Inserted rows 1048001 to 1048500
# ✅ Inserted rows 1048501 to 1049000
# ✅ Inserted rows 1049001 to 1049500
# ✅ Inserted rows 1049501 to 1050000
# ✅ Inserted rows 1050001 to 1050500
# ✅ Inserted rows 1050501 to 1051000
# ✅ Inserted rows 1051001 to 1051500
# ✅ Inserted rows 1051501 to 1052000
# ✅ Inserted rows 1052001 to 1052500
# ✅ Inserted rows 1052501 to 1053000
# ✅ Inserted rows 1053001 to 1053500
# ✅ Inserted rows 1053501 to 1054000
# ✅ Inserted rows 1054001 to 1054500
# ✅ Inserted rows 1054501 to 1055000
# ✅ Inserted rows 1055001 to 1055500
# ✅ Inserted rows 1055501 to 1056000
# ✅ Inserted rows 1056001 to 1056500
# ✅ Inserted rows 1056501 to 1057000
# ✅ Inserted rows 1057001 to 1057500
# ✅ Inserted rows 1057501 to 1058000
# ✅ Inserted rows 1058001 to 1058500
# ✅ Inserted rows 1058501 to 1059000
# ✅ Inserted rows 1059001 to 1059500
# ✅ Inserted rows 1059501 to 1060000
# ✅ Inserted rows 1060001 to 1060500
# ✅ Inserted rows 1060501 to 1061000
# ✅ Inserted rows 1061001 to 1061500
# ✅ Inserted rows 1061501 to 1062000
# ✅ Inserted rows 1062001 to 1062500
# ✅ Inserted rows 1062501 to 1063000
# ✅ Inserted rows 1063001 to 1063500
# ✅ Inserted rows 1063501 to 1064000
# ✅ Inserted rows 1064001 to 1064500
# ✅ Inserted rows 1064501 to 1065000
# ✅ Inserted rows 1065001 to 1065500
# ✅ Inserted rows 1065501 to 1066000
# ✅ Inserted rows 1066001 to 1066500
# ✅ Inserted rows 1066501 to 1067000
# ✅ Inserted rows 1067001 to 1067500
# ✅ Inserted rows 1067501 to 1068000
# ✅ Inserted rows 1068001 to 1068500
# ✅ Inserted rows 1068501 to 1069000
# ✅ Inserted rows 1069001 to 1069500
# ✅ Inserted rows 1069501 to 1070000
# ✅ Inserted rows 1070001 to 1070500
# ✅ Inserted rows 1070501 to 1071000
# ✅ Inserted rows 1071001 to 1071500
# ✅ Inserted rows 1071501 to 1072000
# ✅ Inserted rows 1072001 to 1072500
# ✅ Inserted rows 1072501 to 1073000
# ✅ Inserted rows 1073001 to 1073500
# ✅ Inserted rows 1073501 to 1074000
# ✅ Inserted rows 1074001 to 1074500
# ✅ Inserted rows 1074501 to 1075000
# ✅ Inserted rows 1075001 to 1075500
# ✅ Inserted rows 1075501 to 1076000
# ✅ Inserted rows 1076001 to 1076500
# ✅ Inserted rows 1076501 to 1077000
# ✅ Inserted rows 1077001 to 1077500
# ✅ Inserted rows 1077501 to 1078000
# ✅ Inserted rows 1078001 to 1078500
# ✅ Inserted rows 1078501 to 1079000
# ✅ Inserted rows 1079001 to 1079500
# ✅ Inserted rows 1079501 to 1080000
# ✅ Inserted rows 1080001 to 1080500
# ✅ Inserted rows 1080501 to 1081000
# ✅ Inserted rows 1081001 to 1081500
# ✅ Inserted rows 1081501 to 1082000
# ✅ Inserted rows 1082001 to 1082500
# ✅ Inserted rows 1082501 to 1083000
# ✅ Inserted rows 1083001 to 1083500
# ✅ Inserted rows 1083501 to 1084000
# ✅ Inserted rows 1084001 to 1084500
# ✅ Inserted rows 1084501 to 1085000
# ✅ Inserted rows 1085001 to 1085500
# ✅ Inserted rows 1085501 to 1086000
# ✅ Inserted rows 1086001 to 1086500
# ✅ Inserted rows 1086501 to 1087000
# ✅ Inserted rows 1087001 to 1087500
# ✅ Inserted rows 1087501 to 1088000
# ✅ Inserted rows 1088001 to 1088500
# ✅ Inserted rows 1088501 to 1089000
# ✅ Inserted rows 1089001 to 1089500
# ✅ Inserted rows 1089501 to 1090000
# ✅ Inserted rows 1090001 to 1090500
# ✅ Inserted rows 1090501 to 1091000
# ✅ Inserted rows 1091001 to 1091500
# ✅ Inserted rows 1091501 to 1092000
# ✅ Inserted rows 1092001 to 1092500
# ✅ Inserted rows 1092501 to 1093000
# ✅ Inserted rows 1093001 to 1093500
# ✅ Inserted rows 1093501 to 1094000
# ✅ Inserted rows 1094001 to 1094500
# ✅ Inserted rows 1094501 to 1095000
# ✅ Inserted rows 1095001 to 1095500
# ✅ Inserted rows 1095501 to 1096000
# ✅ Inserted rows 1096001 to 1096500
# ✅ Inserted rows 1096501 to 1097000
# ✅ Inserted rows 1097001 to 1097500
# ✅ Inserted rows 1097501 to 1098000
# ✅ Inserted rows 1098001 to 1098500
# ✅ Inserted rows 1098501 to 1099000
# ✅ Inserted rows 1099001 to 1099500
# ✅ Inserted rows 1099501 to 1100000
# ✅ Inserted rows 1100001 to 1100500
# ✅ Inserted rows 1100501 to 1101000
# ✅ Inserted rows 1101001 to 1101500
# ✅ Inserted rows 1101501 to 1102000
# ✅ Inserted rows 1102001 to 1102500
# ✅ Inserted rows 1102501 to 1103000
# ✅ Inserted rows 1103001 to 1103500
# ✅ Inserted rows 1103501 to 1104000
# ✅ Inserted rows 1104001 to 1104500
# ✅ Inserted rows 1104501 to 1105000
# ✅ Inserted rows 1105001 to 1105500
# ✅ Inserted rows 1105501 to 1106000
# ✅ Inserted rows 1106001 to 1106500
# ✅ Inserted rows 1106501 to 1107000
# ✅ Inserted rows 1107001 to 1107500
# ✅ Inserted rows 1107501 to 1108000
# ✅ Inserted rows 1108001 to 1108500
# ✅ Inserted rows 1108501 to 1109000
# ✅ Inserted rows 1109001 to 1109500
# ✅ Inserted rows 1109501 to 1110000
# ✅ Inserted rows 1110001 to 1110500
# ✅ Inserted rows 1110501 to 1111000
# ✅ Inserted rows 1111001 to 1111500
# ✅ Inserted rows 1111501 to 1112000
# ✅ Inserted rows 1112001 to 1112500
# ✅ Inserted rows 1112501 to 1113000
# ✅ Inserted rows 1113001 to 1113500
# ✅ Inserted rows 1113501 to 1114000
# ✅ Inserted rows 1114001 to 1114500
# ✅ Inserted rows 1114501 to 1115000
# ✅ Inserted rows 1115001 to 1115500
# ✅ Inserted rows 1115501 to 1116000
# ✅ Inserted rows 1116001 to 1116500
# ✅ Inserted rows 1116501 to 1117000
# ✅ Inserted rows 1117001 to 1117500
# ✅ Inserted rows 1117501 to 1118000
# ✅ Inserted rows 1118001 to 1118500
# ✅ Inserted rows 1118501 to 1119000
# ✅ Inserted rows 1119001 to 1119500
# ✅ Inserted rows 1119501 to 1120000
# ✅ Inserted rows 1120001 to 1120500
# ✅ Inserted rows 1120501 to 1121000
# ✅ Inserted rows 1121001 to 1121500
# ✅ Inserted rows 1121501 to 1122000
# ✅ Inserted rows 1122001 to 1122500
# ✅ Inserted rows 1122501 to 1123000
# ✅ Inserted rows 1123001 to 1123500
# ✅ Inserted rows 1123501 to 1124000
# ✅ Inserted rows 1124001 to 1124500
# ✅ Inserted rows 1124501 to 1125000
# ✅ Inserted rows 1125001 to 1125500
# ✅ Inserted rows 1125501 to 1126000
# ✅ Inserted rows 1126001 to 1126500
# ✅ Inserted rows 1126501 to 1127000
# ✅ Inserted rows 1127001 to 1127500
# ✅ Inserted rows 1127501 to 1127609

# %%
import pandas as pd

def load_and_merge_yearly_files(folder_path=None):

        # Get all CSV files in the folder
        csv_files = sorted([f for f in os.listdir(folder_path) if f.endswith('.csv') and '20' in f])
        
        all_dataframes = []

        for file in csv_files:
            file_path = os.path.join(folder_path, file)
            df = pd.read_csv(file_path)
            # print(len(df))
            all_dataframes.append(df)

        # Combine all data
        combined_df = pd.concat(all_dataframes, ignore_index=True)

        return combined_df

data = load_and_merge_yearly_files(folder_path=r"C:\Users\haris\OneDrive\Desktop\Guvi\Projects\Amazon_Sales_Analysis\dataset\cleaned_dataset")

# %%
data.columns
# Out:
# Index(['transaction_id', 'order_date', 'customer_id', 'product_id',
#        'product_name', 'category', 'subcategory', 'brand',
#        'original_price_inr', 'discount_percent', 'discounted_price_inr',
#        'quantity', 'subtotal_inr', 'delivery_charges', 'final_amount_inr',
#        'customer_city', 'customer_state', 'customer_tier',
#        'customer_spending_tier', 'customer_age_group', 'payment_method',
#        'delivery_days', 'delivery_type', 'is_prime_member', 'is_festival_sale',
#        'festival_name', 'customer_rating', 'return_status', 'order_month',
#        'order_year', 'order_quarter', 'product_weight_kg', 'is_prime_eligible',
#        'product_rating', 'clean_order_date', 'clean_original_price_inr',
#        'clean_discount_percent', 'clean_final_amount_inr',
#        'clean_delivery_charges', 'cleaned_customer_rating',
#        'cleaned_product_rating', 'cleaned_customer_city',
#        'cleaned_is_prime_member', 'cleaned_is_prime_eligible',
#        'cleaned_is_festival_sale', 'cleaned_category', 'cleaned_delivery_days',
#        'duplicate_type', 'corrected_price', 'standard_payment_method'],
#       dtype='object')

# %%
data.to_csv(r"C:\Users\haris\OneDrive\Desktop\Guvi\Projects\Amazon_Sales_Analysis\dataset\cleaned_dataset\combined_csv_file.csv", index=False)
